# %% [markdown]
# ### Import

# %%
import gc 
import os
import threading
import tqdm
import time
import copy
import random
from datetime import datetime

import numpy as np
import pandas as pd


from rdkit import Chem

import torch
from torch import Tensor
from torch import nn
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter


from torch_geometric.loader.link_neighbor_loader import LinkNeighborLoader
import torch_geometric.transforms as T
from torch_geometric.data import (
                                    HeteroData,
                                    Data, 
                                    Batch
                                 )   
from torch_geometric.nn import (
                                GATv2Conv,
                                SAGPooling,
                                global_add_pool,
                                HeteroConv,
                                Linear,
                                to_hetero
                                )

from sklearn.model_selection import StratifiedShuffleSplit, KFold, train_test_split, StratifiedKFold
from sklearn.metrics import (
    accuracy_score, 
    precision_score, 
    recall_score, 
    f1_score,
    roc_auc_score, 
    precision_recall_curve, 
    auc, 
    average_precision_score, 
    matthews_corrcoef
    )

# mhgat
import tqdm, os
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import ray

from ray import tune
from ray.tune.schedulers import ASHAScheduler
from ray.tune.search.bayesopt import BayesOptSearch
from ray.tune.search import ConcurrencyLimiter
from ray import train, tune
from ray.tune.search.optuna import OptunaSearch
from ray.tune.schedulers import AsyncHyperBandScheduler

# %% [markdown]
# ### Seed all randomness

# %%
def seed_everything(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Usage example:
seed_everything(29)  # Set the seed to 42

# %% [markdown]
# ### Load HeteroData

# %%
# data_dict = data.to_dict()
fnm = '../prep_data/hetero_graph/hetero_data_dict.pt'
data = torch.load(fnm)

# %%
data
# Out:
# HeteroData(
#   drug={ node_id=[1007] },
#   side_effect={ node_id=[5587] },
#   (drug, known, side_effect)={ edge_index=[2, 132063] },
#   (drug, struct, drug)={
#     edge_index=[2, 15844],
#     edge_attr=[15844]
#   },
#   (drug, word, drug)={
#     edge_index=[2, 83865],
#     edge_attr=[83865]
#   },
#   (drug, target, drug)={
#     edge_index=[2, 3363],
#     edge_attr=[3363]
#   },
#   (drug, se_encoded, drug)={
#     edge_index=[2, 65854],
#     edge_attr=[65854]
#   },
#   (side_effect, name, side_effect)={
#     edge_index=[2, 299170],
#     edge_attr=[299170]
#   },
#   (side_effect, dg_encoded, side_effect)={
#     edge_index=[2, 101114],
#     edge_attr=[101114]
#   },
#   (side_effect, atc, side_effect)={
#     edge_index=[2, 26140],
#     edge_attr=[26140]
#   }
# )

# %% [markdown]
# ### Load Transformation Maps

# %%
DB_TO_ID_DICT = {}
drug_id_mol_graph_tup = []
ID_TO_DB_DICT = {}
MEDRAID_TO_ID_DICT = {}
ID_TO_MEDRAID_DICT = {}

# %%
dict_list = [DB_TO_ID_DICT, ID_TO_DB_DICT, MEDRAID_TO_ID_DICT, ID_TO_MEDRAID_DICT, drug_id_mol_graph_tup]
file_names = ['db_to_id.pt', 'id_to_db.pt', 'uml_to_id.pt', 'id_to_uml.pt', 'drug_to_mol.pt']

for data_dict, fnm in zip(dict_list, file_names):
    full_path = f"../prep_data/hetero_graph/{fnm}"
    loaded_data = torch.load(full_path)
    
    if isinstance(data_dict, dict):
        data_dict.update(loaded_data)
    elif isinstance(data_dict, list):
        data_dict.extend(loaded_data)
    else:
        # If it's neither a dict nor a list, just replace it
        index = dict_list.index(data_dict)
        dict_list[index] = loaded_data

# %% [markdown]
# ### HeteroData Undirected

# %%
data = T.ToUndirected()(data)

# %% [markdown]
# ### Molecule Featurization Utils

# %%
# Bond featurization
def get_bond_features(bond):
    # Simplified list of bond types
    permitted_bond_types = [Chem.rdchem.BondType.SINGLE, Chem.rdchem.BondType.DOUBLE, 
                            Chem.rdchem.BondType.TRIPLE, Chem.rdchem.BondType.AROMATIC, 'Unknown']
    bond_type = bond.GetBondType() if bond.GetBondType() in permitted_bond_types else 'Unknown'
    
    # Features: Bond type, Is in a ring
    features = one_of_k_encoding_unk(bond_type, permitted_bond_types) \
               + [bond.IsInRing()]
    
    return np.array(features, dtype=np.float32)

def get_mol_edge_list_and_feat_mtx(mol_graph):
    n_features = [(atom.GetIdx(), atom_features(atom)) for atom in mol_graph.GetAtoms()]
    n_features.sort() # to make sure that the feature matrix is aligned according to the idx of the atom
    _, n_features = zip(*n_features)
    # n_features = torch.stack(n_features)
    n_features = torch.tensor(n_features, dtype=torch.float32)

    edge_list = torch.LongTensor([(b.GetBeginAtomIdx(), b.GetEndAtomIdx()) for b in mol_graph.GetBonds()])
    undirected_edge_list = torch.cat([edge_list, edge_list[:, [1, 0]]], dim=0) if len(edge_list) else edge_list 

    # Extract bond features
    bond_features = [get_bond_features(bond) for bond in mol_graph.GetBonds()]
    undirected_bond_features = bond_features + bond_features  # duplicate for undirected edges
    edge_attr = torch.tensor(undirected_bond_features, dtype=torch.float32)

    return undirected_edge_list.T, n_features, edge_attr 


def one_of_k_encoding_unk(x, allowable_set):
    if x not in allowable_set:
        x = allowable_set[-1]
    return list(map(lambda s: x == s, allowable_set))

def all_of_k_encoding_unk(x, allowable_set):
    enc = np.zeros(len(allowable_set))
    for idx, side_eff_id in enumerate(allowable_set):
        if side_eff_id in x:
            enc[idx] = 1
    return enc
    
def atom_features(atom,
                explicit_H=True,
                use_chirality=False):

    results = one_of_k_encoding_unk(
        atom.GetSymbol(),
        ['C','N','O', 'S','F','Si','P', 'Cl','Br','Mg','Na','Ca','Fe','As','Al','I','B','V','K','Tl',
            'Yb','Sb','Sn','Ag','Pd','Co','Se','Ti','Zn','H', 'Li','Ge','Cu','Au','Ni','Cd','In',
            'Mn','Zr','Cr','Pt','Hg','Pb','Unknown'
        ]) + [atom.GetDegree()/10, atom.GetImplicitValence(), 
                atom.GetFormalCharge(), atom.GetNumRadicalElectrons()] + \
                one_of_k_encoding_unk(atom.GetHybridization(), [
                Chem.rdchem.HybridizationType.SP, Chem.rdchem.HybridizationType.SP2,
                Chem.rdchem.HybridizationType.SP3, Chem.rdchem.HybridizationType.
                                    SP3D, Chem.rdchem.HybridizationType.SP3D2
                ]) + [atom.GetIsAromatic()]
    # In case of explicit hydrogen(QM8, QM9), avoid calling `GetTotalNumHs`
    if explicit_H:
        results = results + [atom.GetTotalNumHs()]

    if use_chirality:
        try:
            results = results + one_of_k_encoding_unk(
            atom.GetProp('_CIPCode'),
            ['R', 'S']) + [atom.HasProp('_ChiralityPossible')]
        except:
            results = results + [False, False
                            ] + [atom.HasProp('_ChiralityPossible')]

    results = np.array(results).astype(np.float32)

    return results #torch.from_numpy(results)

# %% [markdown]
# ### Molecule Featurization

# %%
MOL_EDGE_LIST_FEAT_MTX = {DB_TO_ID_DICT[drug_id]: get_mol_edge_list_and_feat_mtx(mol) 
                                for drug_id, mol in drug_id_mol_graph_tup}
len(MOL_EDGE_LIST_FEAT_MTX.keys())
# Out:
# /home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:230.)
# /home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3277.)
# 1007

# %%
MOL_EDGE_LIST_FEAT_MTX[998][1].shape, MOL_EDGE_LIST_FEAT_MTX[998][2].shape
# Out:
# (torch.Size([57, 55]), torch.Size([16, 6]))

# %% [markdown]
# ### CV Split

# %%
def get_kfold_data(data, k=10, shuffle=True, num_neighbors=[10, 4], batch_size=64):
    kf = KFold(n_splits=k, shuffle=shuffle)
    kf.get_n_splits()
    train_val_data_X = data['drug', 'known', 'side_effect'].edge_index.T.numpy()
    for train_index, test_index in kf.split(train_val_data_X):
        train_index_, valid_index_ = train_test_split(train_index, test_size=0.1)
        train_set = train_index_
        valid_set = valid_index_
        
        train_data_cv = copy.deepcopy(data)
        train_data_cv['drug', 'known', 'side_effect'].edge_index = torch.tensor(train_val_data_X[train_set].T)
        train_data_cv['side_effect', 'rev_known', 'drug'].edge_index = torch.tensor(train_val_data_X[train_set].T)[[1, 0]]
    
        val_data_cv = copy.deepcopy(data)
        val_data_cv['drug', 'known', 'side_effect'].edge_index = torch.tensor(train_val_data_X[valid_set].T)
        val_data_cv['side_effect', 'rev_known', 'drug'].edge_index = torch.tensor(train_val_data_X[valid_set].T)[[1, 0]]
    
        
        
        test_data_cv = copy.deepcopy(data)
        test_data_cv['drug', 'known', 'side_effect'].edge_index = torch.tensor(train_val_data_X[test_index].T)
        test_data_cv['side_effect', 'rev_known', 'drug'].edge_index = torch.tensor(train_val_data_X[test_index].T)[[1, 0]]
        
        # use RandomLinkSplit to get disjoint train ratio an other pyg transforms
        transform = T.RandomLinkSplit(
            num_val=0.0,
            num_test=0.0,
            disjoint_train_ratio=0.3236238313900354,
            neg_sampling_ratio=0.0,
            add_negative_train_samples=False,
            edge_types=('drug', 'known', 'side_effect'),
            rev_edge_types=('side_effect', 'rev_known', 'drug'), 
        )
        train_cv, _, _ = transform(train_data_cv)
        
        transform = T.RandomLinkSplit(
            num_val=0.0,
            num_test=0.0,
            disjoint_train_ratio=0.99,
            neg_sampling_ratio=1.0,
            add_negative_train_samples=True,
            edge_types=('drug', 'known', 'side_effect'),
            rev_edge_types=('side_effect', 'rev_known', 'drug'), 
        )
        
        val_cv, _, _ = transform(val_data_cv)
       

        test_cv, _, _ = transform(test_data_cv)
        # Define seed edges:
        edge_label_index = train_cv['drug', 'known', 'side_effect'].edge_label_index
        edge_label = train_cv['drug', 'known', 'side_effect'].edge_label

        train_loader = LinkNeighborLoader(
            data=train_cv,
            num_neighbors=num_neighbors,
            neg_sampling_ratio=1.0,
            edge_label_index=(("drug", "known", "side_effect"), edge_label_index),
            edge_label=edge_label,
            batch_size=batch_size,
            shuffle=True,
            # disjoint=True,
        )
        
        edge_label_index = val_cv['drug', 'known', 'side_effect'].edge_label_index
        edge_label = val_cv['drug', 'known', 'side_effect'].edge_label
        # num_neighbors is a dictionary, it uses the specified number for each edge type
        val_loader = LinkNeighborLoader(
            data=val_cv,
            num_neighbors=num_neighbors,
            edge_label_index=(("drug", "known", "side_effect"), edge_label_index),
            edge_label=edge_label,
            batch_size=batch_size,
            shuffle=False,
        )
        
        
        
        edge_label_index = test_cv['drug', 'known', 'side_effect'].edge_label_index
        edge_label = test_cv['drug', 'known', 'side_effect'].edge_label

        test_loader = LinkNeighborLoader(
            data=test_cv,
            num_neighbors=num_neighbors,
            edge_label_index= (("drug", "known", "side_effect"), edge_label_index), 
            edge_label=edge_label,
            batch_size=batch_size,
            shuffle=False
        )
        yield train_loader, val_loader, test_loader

# %% [markdown]
# ### Hyper Param - DataLoader

# %%
def load_data(config):
    # data_dict = data.to_dict()
    fnm = '/root/SDV-HGNN/prep_data/hetero_graph/hetero_data_dict.pt'
    data = torch.load(fnm)
    # create undirected edges for drug known side-effects
    data = T.ToUndirected()(data)
    
    # use RandomLinkSplit to get disjoint train ratio an other pyg transforms
    transform = T.RandomLinkSplit(
        num_val=0.1,
        num_test=0.1,
        disjoint_train_ratio=config['dtr'], #0.3
        neg_sampling_ratio=1.0,
        add_negative_train_samples=False,
        edge_types=('drug', 'known', 'side_effect'),
        rev_edge_types=('side_effect', 'rev_known', 'drug'), 
    )
    train_data, val_data, test_data = transform(data)
    
    num_neighbors=[config['num_neigh1'],config['num_neigh2']]  #[8, 5]
    batch_size=config['batch_size'] #64   

    # Define seed edges:
    edge_label_index = train_data['drug', 'known', 'side_effect'].edge_label_index
    edge_label = train_data['drug', 'known', 'side_effect'].edge_label

    train_loader = LinkNeighborLoader(
        data=train_data,
        num_neighbors=num_neighbors,
        neg_sampling_ratio=1.0,
        edge_label_index=(("drug", "known", "side_effect"), edge_label_index),
        edge_label=edge_label,
        batch_size=batch_size,
        shuffle=True,
        # disjoint=True,
    )
    
    edge_label_index = val_data['drug', 'known', 'side_effect'].edge_label_index
    edge_label = val_data['drug', 'known', 'side_effect'].edge_label
    # num_neighbors is a dictionary, it uses the specified number for each edge type
    val_loader = LinkNeighborLoader(
        data=val_data,
        num_neighbors=num_neighbors,
        edge_label_index=(("drug", "known", "side_effect"), edge_label_index),
        edge_label=edge_label,
        batch_size=batch_size,
        shuffle=False,
    )
    
    
    
    edge_label_index = test_data['drug', 'known', 'side_effect'].edge_label_index
    edge_label = test_data['drug', 'known', 'side_effect'].edge_label

    test_loader = LinkNeighborLoader(
        data=test_data,
        num_neighbors=num_neighbors,
        edge_label_index= (("drug", "known", "side_effect"), edge_label_index), 
        edge_label=edge_label,
        batch_size=batch_size,
        shuffle=False
    )
    return data, train_loader, val_loader, test_loader

# %% [markdown]
# ### Model

# %% [markdown]
# #### MHGNN Hetero

# %%
class HeteroMHGNN(nn.Module):
    def __init__(self, metadata, in_channels, outer_n_head, hidden_dims, heads, use_edge_attr=None):
        super().__init__()
        
        self.convs = nn.ModuleList()
        self.norms = nn.ModuleDict()
        self.skips = nn.ModuleDict()
        self.final_norms = nn.ModuleDict()
        hidden_dims = [hidden_dims] * outer_n_head
        heads = [heads] * outer_n_head
        # Define which edge types should use edge attributes
        if use_edge_attr is None:
            use_edge_attr = {edge_type: False for edge_type in metadata[1]}
        
        for i, (out_dim, head) in enumerate(zip(hidden_dims, heads)):
            conv_dict = {}
            for edge_type in metadata[1]:
                src, _, dst = edge_type
                if i == 0:
                    in_channels = in_channels
                else:
                    in_channels = hidden_dims[i-1] * heads[i-1]
                
                if use_edge_attr[edge_type]:
                    conv_dict[edge_type] = GATv2Conv(in_channels, out_dim, heads=head, add_self_loops=False, edge_dim=1)
                else:
                    conv_dict[edge_type] = GATv2Conv(in_channels, out_dim, heads=head, add_self_loops=False)
            
            self.convs.append(HeteroConv(conv_dict, aggr='sum'))
            
            for node_type in metadata[0]:
                self.norms[f'{node_type}_{i}'] = nn.LayerNorm(out_dim * head)
                if i == 0:
                    self.skips[f'{node_type}_{i}'] = Linear(in_channels, out_dim * head)
                else:
                    self.skips[f'{node_type}_{i}'] = Linear(hidden_dims[i-1] * heads[i-1], out_dim * head)
        
        self.node_types = metadata[0]
        for node_type in metadata[0]:
            self.final_norms[f'{node_type}'] = nn.LayerNorm(out_dim * head *len(heads))
        
        # Initialize skips with xavier init
        for skip in self.skips.values():
            nn.init.xavier_uniform_(skip.weight)
            nn.init.zeros_(skip.bias)

    def forward(self, x_dict, edge_index_dict, edge_attr_dict):
        x_repr_dict = {node_type: [] for node_type in self.node_types}
        # edge_attr_dict = {key: value.to(torch.float32) for key, value in edge_attr_dict.items()}

        
        for i, conv in enumerate(self.convs):
            skip_x = {}
            for node_type in self.node_types:
                skip_x[node_type] = self.skips[f'{node_type}_{i}'](x_dict[node_type])
            
            x_dict_new = conv(x_dict, edge_index_dict, edge_attr_dict)
            
            for node_type in self.node_types:
                # skip_x = self.skips[f'{node_type}_{i}'](x_dict[node_type])
                x = x_dict_new[node_type]
                x = self.norms[f'{node_type}_{i}'](x) + skip_x[node_type]
                x = self.norms[f'{node_type}_{i}'](x)
                x = F.elu(x)
                x_repr_dict[node_type].append(x)
                x_dict[node_type] = x
        
        # Concatenate all representations for each node type
        for node_type in self.node_types:
            x_repr_dict[node_type] = self.final_norms[f'{node_type}'](torch.cat(x_repr_dict[node_type], dim=1))
        
        return x_repr_dict

# Specify which edge types should use edge attributes
use_edge_attr = {
    ('drug', 'known', 'side_effect'): False,
    ('drug', 'struct', 'drug'): True,
    ('drug', 'word', 'drug'): True,
    ('drug', 'target', 'drug'): True,
    ('drug', 'se_encoded', 'drug'): True,
    ('side_effect', 'name', 'side_effect'): True,
    ('side_effect', 'dg_encoded', 'side_effect'): True,
    ('side_effect', 'atc', 'side_effect'): True,
    ('side_effect', 'rev_known', 'drug'): False
}

# %% [markdown]
# #### MHGNN - Outer HGNN

# %%
# class MHGNN(nn.Module):
#     def __init__(self, input_dim, outer_n_head, hidden_dims, heads):
#         super().__init__()
#         self.GATLayers = nn.ModuleList()
#         self.norms = nn.ModuleList() 
#         self.skips = nn.ModuleList()
#         for i in range(outer_n_head):
#             self.GATLayers.append(GATv2Conv(input_dim, hidden_dims, heads=heads, 
#                                     add_self_loops=False, name=f'GATLayer{i}'))
#             self.norms.append(nn.LayerNorm(hidden_dims * heads))
#             self.skips.append(nn.Linear(input_dim, hidden_dims * heads))
#             input_dim = hidden_dims * heads     
        
#         # # # initialize skips with xavier init
#         for skip in self.skips:
#             nn.init.xavier_uniform_(skip.weight)
#             nn.init.zeros_(skip.bias)

#     def forward(self, x, edge_index, edge_attr):
#         x_repr = []
#         for idx, (layer, skip, norm) in enumerate(zip(self.GATLayers, self.skips, self.norms)): # norm, self.norms
#             skip_x = skip(x)
#             x = layer(x, edge_index)
#             x = norm(x) + skip_x  # Add skip connection
#             x = norm(x)     # Apply normalization
#             x = F.elu(x)    # Apply activation
#             x_repr.append(x)
#             # x = F.elu(norm(x))
#             # x += skip_x
#             # x_repr.append(F.elu(x))
#             # if idx < len(self.GATLayers) - 1:
#             #     x = F.elu(x) # norm(x)
#         x_repr = torch.cat(x_repr, dim=1)
#         return x_repr

# %% [markdown]
# #### DVModel

# %%
class DrugInterView_Block(nn.Module):
    def __init__(self, n_heads, in_features, head_out_feats):
        super().__init__()
        self.n_heads = n_heads
        self.in_features = in_features
        self.out_features = head_out_feats

        self.feature_conv = GATv2Conv(in_features, head_out_feats, n_heads, edge_dim=6)

        self.readout = SAGPooling(n_heads * head_out_feats, min_score=-1)

    def forward(self, mol_data):
        mol_data.x = self.feature_conv(mol_data.x, mol_data.edge_index, mol_data.edge_attr)
        mol_data_att_x, att_edge_index, att_edge_attr, h_att_batch, att_perm, h_att_scores = self.readout(mol_data.x, mol_data.edge_index, batch=mol_data.batch)

        mol_data_global_graph_emb = global_add_pool(mol_data_att_x, h_att_batch)

        return mol_data, mol_data_global_graph_emb, h_att_scores, h_att_batch

# %%
class FinalDrugMolEmb(nn.Module):
    def __init__(self, in_features, mol_n_head, heads_out_feat_params, blocks_params):
        super().__init__()
        self.in_features = in_features
        self.n_blocks = mol_n_head # len(blocks_params)

        self.inital_norm = nn.LayerNorm(self.in_features)

        self.blocks = nn.ModuleList()
        self.net_norms = nn.ModuleList()

        for i in range(mol_n_head):
            block = DrugInterView_Block(blocks_params, in_features, heads_out_feat_params)
            self.blocks.append(block)
            self.net_norms.append(nn.LayerNorm(heads_out_feat_params * blocks_params))
            in_features = heads_out_feat_params * blocks_params
       
    def forward(self, mol_data):
        repr_mol = []
        mol_data.x = self.inital_norm(mol_data.x)
        attention_weights = []
        attention_batch = []
        for idx, (block, norm) in enumerate(zip(self.blocks, self.net_norms)):
            mol_data, mol_data_global_graph_emb, mol_data_att_x, h_att_batch = block(mol_data)
            attention_weights.append(mol_data_att_x)
            attention_batch.append((mol_data.batch, h_att_batch))
            repr_mol.append(mol_data_global_graph_emb)
            if idx < len(self.blocks) - 1:
                mol_data.x = F.elu(norm(mol_data.x))
        # concat all the global graph embeddings
        mol_data_global_graph_emb = torch.cat(repr_mol, dim=1)
        return mol_data_global_graph_emb, attention_weights, attention_batch

# %%
class DVModel(torch.nn.Module):
    def __init__(self, config, n_side_effect, edge_metadata):
        super().__init__()
        # Instantiate node embeddings:
        outer_emb_dim = config['mol_heads_out'] * config['mol_block_param'] * config['mol_n_head']
        
        self.seff_emb = torch.nn.Embedding(n_side_effect, outer_emb_dim)
        # DV for Drug
        self.drug_emb = FinalDrugMolEmb(in_features=55, mol_n_head=config['mol_n_head'],
                                        heads_out_feat_params=config['mol_heads_out'], 
                                        blocks_params=config['mol_block_param']) 
        # heads_out_feat_params=[64, 64], blocks_params=[3, 3])

        
        self.inital_norm_outer_drug = nn.LayerNorm(outer_emb_dim)
        # self.inital_norm_outer_se = nn.LayerNorm(outer_emb_dim)
        
        # gnn_model = MHGNN(input_dim=outer_emb_dim, outer_n_head=config['outer_n_head'],
        #                   hidden_dims=config['outer_hidden_dims'], #[128, 128]
        #                   heads=config['outer_block']) 
        # hidden_dims=[64, 64, 64], heads=[2, 2, 2])

        # gnn_model = to_hetero(gnn_model, metadata=edge_metadata)

        gnn_model = HeteroMHGNN(edge_metadata, in_channels=outer_emb_dim, outer_n_head=config['outer_n_head'], 
                                hidden_dims=config['outer_hidden_dims'], heads=config['outer_block'], use_edge_attr=use_edge_attr)
        classifier_model = VanillaClassifier()
        
        # Instantiate Outer GNNs
        self.gnn = gnn_model # outer message passing
        
        # Instantiate classifier:
        self.classifier = classifier_model
        
        torch.nn.init.xavier_uniform_(self.seff_emb.weight)
        
    def __create_graph_data(self, drug_ids, device):
        drug_ids_ = drug_ids.cpu().numpy().astype(int).tolist()
        final_data = []
        for id in drug_ids_:
            _ = MOL_EDGE_LIST_FEAT_MTX[id]
            final_data.append(Data(x= _[1]  , edge_index=_[0], edge_attr=_[2]))
        return Batch.from_data_list(final_data).to(device)        
       
    
    def forward(self, data: HeteroData) -> Tensor:
        drug_list_of_graph_data = self.__create_graph_data(data["drug"].node_id, data["drug"].node_id.device)
        
        drug_dv, attention_weights, h_att_batch = self.drug_emb(drug_list_of_graph_data)
        
        # layer normalization of input features for outer gnn:
        x_dict = {
            "drug":  self.inital_norm_outer_drug(drug_dv),
            "side_effect": self.seff_emb(data["side_effect"].node_id)
        }

        # `x_dict` holds feature matrices of all node types
        # `edge_index_dict` holds all edge indices of all edge types
        # x_dict = self.gnn(x_dict, data.edge_index_dict, data.edge_attr_dict)
        # Forward pass
        x_dict = self.gnn(x_dict, data.edge_index_dict, data.edge_attr_dict)
        pred = self.classifier(
            x_dict["drug"],
            x_dict["side_effect"],
            data["drug", "known", "side_effect"].edge_label_index,
        )

        return pred, attention_weights, h_att_batch

# %% [markdown]
# #### Edge Classifier

# %%
# Our final classifier applies the hammard-product between source and destination
# node embeddings to derive edge-level predictions:
class VanillaClassifier(torch.nn.Module):
    def forward(self, x_drug: Tensor, x_se: Tensor, edge_label_index: Tensor) -> Tensor:
        # Convert node embeddings to edge-level representations:
        edge_feat_drug = x_drug[edge_label_index[0]]
        edge_feat_se = x_se[edge_label_index[1]]

        # Apply hammard-product to get a prediction per supervision edge:
        return (edge_feat_drug * edge_feat_se).sum(dim=-1)

# %% [markdown]
# ### Train Utils

# %% [markdown]
# #### Train Loop

# %%
def do_train_compute(batch, device, model):
    # batch = batch.to(device)
    pred, _, _ = model(batch)
    actual = batch["drug", "known", "side_effect"].edge_label
    return pred, actual

# def do_train_compute(batch, device, model):
#     # batch = batch.to(device)
#     pred = model(batch)
#     actual = batch.edge_label
#     return pred, actual


def evaluate_metrics(probas_pred, ground_truth):
    # compute binary classification metrics using sklearn
    # convert to numpy array
    probas_pred = probas_pred.numpy()
    
    ground_truth = ground_truth.numpy()
    
    # convert to binary predictions
    binary_pred = np.where(probas_pred > 0.5, 1, 0)

    
    # compute metrics
    accuracy = accuracy_score(ground_truth, binary_pred)
    precision = precision_score(ground_truth, binary_pred)
    recall = recall_score(ground_truth, binary_pred)
    f1 = f1_score(ground_truth, binary_pred)
    roc_auc = roc_auc_score(ground_truth, probas_pred)
    precision_, recall_, _ = precision_recall_curve(ground_truth, probas_pred)
    pr_auc = auc(recall_, precision_)
    average_precision = average_precision_score(ground_truth, probas_pred)
    return accuracy, precision, recall, f1, roc_auc, pr_auc, average_precision

def train_loop(model, model_name, writer, train_loader, val_loader, loss_fn, optimizer, n_epochs, device, scheduler=None, early_stopping_patience=3, early_stopping_counter=0):
    early_stop = False
    best_val_metrics = -float("inf") #-float("inf")
    best_model_path = f"saved_models/{model_name}/best_model.pth"
    # make best_model_path parent directory if it doesn't exist
    os.makedirs(os.path.dirname(best_model_path), exist_ok=True)
    
    print("Starting training loop at", datetime.today().strftime("%Y-%m-%d %H:%M:%S"))
    
    total_train_val_steps = len(train_loader) + len(val_loader)
    epoch_progress_bar = tqdm.notebook.tqdm(range(1, (total_train_val_steps*n_epochs)+1), desc="MiniBatches")
    epoch = 0
    for _ in epoch_progress_bar:
        epoch += 1
        start_time = time.time()
        train_loss = 0
        val_loss = 0
        train_probas_pred = []
        train_ground_truth = []
        val_probas_pred = []
        val_ground_truth = []
        print("Epoch", epoch)
        
        model.train()
        for idx, batch in enumerate(train_loader):
            batch = batch.to(device)
            lr = optimizer.param_groups[0]['lr']
            optimizer.zero_grad()
            out, actual = do_train_compute(batch, device, model)
            pred = torch.sigmoid(out)
            train_probas_pred.append(pred.detach().cpu())
            train_ground_truth.append(actual.detach().cpu())
            loss = loss_fn(out, actual)
            loss.backward()
            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Adjust max_norm as needed

            optimizer.step()
            train_loss += loss.item()
            epoch_progress_bar.set_postfix_str(f"Epoch {epoch} - LR {lr:.7f} - Train Batch {idx+1}/{len(train_loader)} - Train loss: {train_loss/(idx+1):.4f}")
            epoch_progress_bar.update()
            writer.add_scalar("Training Loss MiniBatch", loss.item(), idx)
            batch = batch.to("cpu")
            # if scheduler is not None: # cosine annealing scheduler
            #     scheduler.step()
        
        train_loss /= len(train_loader)
        writer.add_scalar("Training Loss Epoch", train_loss, epoch)
        model.eval()
        with torch.no_grad():
            train_probas_pred = torch.cat(train_probas_pred, dim=0)
            train_ground_truth = torch.cat(train_ground_truth, dim=0)
            train_accuracy, train_precision, train_recall, train_f1, \
                train_roc_auc, train_pr_auc, train_average_precision = evaluate_metrics(train_probas_pred, train_ground_truth)
            writer.add_scalar("Training Accuracy", train_accuracy, epoch)
            writer.add_scalar("Training Precision", train_precision, epoch)
            writer.add_scalar("Training Recall", train_recall, epoch)
            writer.add_scalar("Training F1", train_f1, epoch)
            writer.add_scalar("Training ROC AUC", train_roc_auc, epoch)
            writer.add_scalar("Training PR AUC", train_pr_auc, epoch)
            writer.add_scalar("Training Average Precision", train_average_precision, epoch)

            for idx_, batch in enumerate(val_loader):
                batch = batch.to(device)
                out, actual = do_train_compute(batch, device, model)
                pred = torch.sigmoid(out)
                val_probas_pred.append(pred.detach().cpu())
                val_ground_truth.append(actual.detach().cpu())
                loss = loss_fn(out, actual)
                val_loss += loss.item()
                epoch_progress_bar.set_postfix_str(f"Epoch {epoch} - LR {lr:.7f} - Val Batch {idx_+1}/{len(val_loader)} - Val loss: {val_loss/(idx+1):.4f}")
                epoch_progress_bar.update()
                writer.add_scalar("Validation Loss MiniBatch", loss.item(), idx_)
                batch = batch.to("cpu")
            val_loss /= len(val_loader)
            val_probas_pred = torch.cat(val_probas_pred, dim=0)
            val_ground_truth = torch.cat(val_ground_truth, dim=0)
            val_accuracy, val_precision, val_recall, val_f1, \
                val_roc_auc, val_pr_auc, val_average_precision = evaluate_metrics(val_probas_pred, val_ground_truth)
            
            writer.add_scalar("Validation Loss Epoch", val_loss, epoch)
            writer.add_scalar("Validation Accuracy", val_accuracy, epoch)
            writer.add_scalar("Validation Precision", val_precision, epoch)
            writer.add_scalar("Validation Recall", val_recall, epoch)
            writer.add_scalar("Validation F1", val_f1, epoch)
            writer.add_scalar("Validation ROC AUC", val_roc_auc, epoch)
            writer.add_scalar("Validation PR AUC", val_pr_auc, epoch)
            writer.add_scalar("Validation Average Precision", val_average_precision, epoch)
            
            if val_f1 > best_val_metrics:
                best_val_metrics = val_f1
                early_stopping_counter = 0
                torch.save(model.state_dict(), best_model_path)
                print("New best model saved!") 
            else:
                early_stopping_counter += 1
                print("Early stopping counter:", early_stopping_counter)
                if early_stopping_counter >= early_stopping_patience:
                    print("Early stopping triggered!")
                    early_stop = True
        
        if scheduler is not None:
            scheduler.step(val_f1) #
      
        
        epoch_progress_bar.set_postfix_str("Train loss: {:.4f}, Train f1: {:.4f}, Train auc: {:.4f}, Train pr_auc: {:.4f},\
                                            Val loss: {:.4f}, Val f1: {:.4f}, Val auc: {:.4f}, Val pr_auc: {:.4f},\
                                            Best val f1: {:.4f}".format(train_loss, train_f1, train_roc_auc, train_pr_auc,\
                                            val_loss, val_f1, val_roc_auc, val_pr_auc, best_val_metrics))
        epoch_progress_bar.update()
        print("Epoch Number:", epoch)   
        print("Epoch time:", time.time() - start_time)
        print("Train loss:", train_loss)
        print("Train accuracy:", train_accuracy)
        print("Train precision:", train_precision)
        print("Train recall:", train_recall)
        print("Train f1:", train_f1)
        print("Train roc_auc:", train_roc_auc)
        print("Train pr_auc:", train_pr_auc)
        print("Train average_precision:", train_average_precision)
        
        print("Val loss:", val_loss)
        print("Val accuracy:", val_accuracy)
        print("Val precision:", val_precision)
        print("Val recall:", val_recall)
        print("Val f1:", val_f1)
        print("Val roc_auc:", val_roc_auc)
        print("Val pr_auc:", val_pr_auc)
        print("Val average_precision:", val_average_precision)
        print("Best val_f1:", val_f1)
        print()
        train.report({"val_f1": val_f1})
        if early_stop:
            break
        if epoch == n_epochs:
            print("Training completed!")
            break
    
    # load best model 
    # model.load_state_dict(torch.load(best_model_path))
    return {"val_f1": best_val_metrics, "train_loss": train_loss}

# %% [markdown]
# ### Run RayTune

# %%
def ray_tune_sdv(config):
    model_name ="ray_sdvhgnn"
    # Define the log directory where TensorBoard logs will be stored
    log_dir = f"logs/{model_name}/" + datetime.now().strftime("%Y%m%d-%H%M%S")
    # log_dir = f"{log_dir}/{ray.train.get_context().get_trial_dir()}"
    os.makedirs(log_dir, exist_ok=True)
    # Create a SummaryWriter
    writer = SummaryWriter(log_dir)
    
    # load your data
    data, train_loader, val_loader, test_loader = load_data(config['load_data'])
    # Initialize model
    sdv_model = DVModel(config['model'], data["side_effect"].num_nodes, data.metadata())

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Device: '{device}'")

    sdv_model = sdv_model.to(device)
    
    # Define loss function and optimizer
    criterion = F.binary_cross_entropy_with_logits
    optimizer = torch.optim.Adam(sdv_model.parameters(), lr=config['training']['lr'], weight_decay=config['training']['decay']) #, weight_decay=5e-4
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode="max", factor=0.5, patience=2, min_lr=1e-6
        )
    # scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lambda epoch: 0.96 ** (epoch))
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, 
    #                                                                  T_0=len(train_loader), 
    #                                                                  T_mult=1, 
    #                                                                  eta_min=1e-5, 
    #                                                                  verbose=False)
    # on plateau scheduler
    # scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, verbose=False, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=1e-6, eps=1e-08)
    
    print(f"Total Number of Parameters: {sum(p.numel() for p in sdv_model.parameters())}")
    print(f"Total Number of Trainable Parameters: {sum(p.numel() for p in sdv_model.parameters() if p.requires_grad)}")
  
    sdv_model_metric = train_loop(sdv_model, model_name, writer, train_loader, val_loader, criterion, optimizer, 
                        n_epochs=config['training']['n_epochs'], device=device, scheduler=scheduler,
                        early_stopping_patience=5)
    return sdv_model_metric

# %%
config = {
    'load_data': {
        'dtr': tune.quniform(0.1, 0.7, 0.05),
        'batch_size': tune.choice([64, 128, 256]), #16, 32, 
        'num_neigh1': tune.qrandint(4, 12, 2), #tune.choice(list(range(4, 12, 2))),
        'num_neigh2': tune.qrandint(4, 12, 2), #tune.choice(list(range(4, 12, 2))),
        # 'num_neigh3': tune.qrandint(4, 12, 2), #tune.choice(list(range(4, 12, 2))),
        # 'num_neigh': tune.choice([[8, 5], [6, 4], [4, 8], [5, 5], [7, 5]])
    },
    'training': {
        'lr':  tune.loguniform(1e-5, 1e-2),
        'n_epochs': tune.qrandint(5, 21, 5),
        'decay':  tune.loguniform(1e-5, 1e-2)
    },
    'model': {
        'mol_n_head': tune.choice([2, 3, 4]),
        'mol_heads_out': tune.choice([16, 32, 64, 128]),
        'mol_block_param': tune.choice([2, 3]), #1
        
        'outer_n_head': tune.choice([2, 3]), # 1
        'outer_hidden_dims': tune.choice([32, 64, 128, 256]),
        'outer_block': tune.choice([2, 3]) #1
    }
}

# %%
os.makedirs('ray_results_sdv', exist_ok=True)

# %%
ray.init(num_cpus=4, num_gpus=1)
scheduler = AsyncHyperBandScheduler(time_attr="training_iteration",
                                     max_t=20, grace_period=3)

algo = OptunaSearch()  #
trainable_with_resources = tune.with_resources(ray_tune_sdv, {"cpu": 4, "gpu":1})

def stop_fn(trial_id: str, result: dict) -> bool:
    # global trial_done
    early_stop = result.get('early_stop', False)
    print("Here Global ", early_stop)
    return early_stop #trial_id.info["early_stop"]


tuner = tune.Tuner(
    trainable_with_resources,
    tune_config=tune.TuneConfig(
        metric="val_f1",
        mode="max",
        search_alg=algo,
        scheduler=scheduler,
        num_samples=20,
    ),
    run_config=train.RunConfig(
        # stop={"training_iteration": 5},
        local_dir='/root/SDV-HGNN/hyperparam/ray_results_sdv',
        log_to_file=True,
        verbose=1, 
        # stop={"training_iteration" : 1}
    ),
    
    param_space=config,
)
# Out:
# 2024-08-05 18:17:57,342	INFO worker.py:1642 -- Started a local Ray instance.

# %%
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-08-05 19:02:02</td></tr>
# <tr><td>Running for: </td><td>00:44:04.44        </td></tr>
# <tr><td>Memory:      </td><td>10.6/19.4 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=4<br>Bracket: Iter 12.000: None | Iter 3.000: 0.7658577937429771<br>Logical resource usage: 4.0/4 CPUs, 1.0/1 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc                 </th><th style="text-align: right;">  load_data/batch_size</th><th style="text-align: right;">  load_data/dtr</th><th style="text-align: right;">  load_data/num_neigh1</th><th style="text-align: right;">  load_data/num_neigh2</th><th style="text-align: right;">  model/mol_block_para
# m</th><th style="text-align: right;">  model/mol_heads_out</th><th style="text-align: right;">  model/mol_n_head</th><th style="text-align: right;">  model/outer_block</th><th style="text-align: right;">    model/outer_hidden_d
# ims</th><th style="text-align: right;">  model/outer_n_head</th><th style="text-align: right;">  training/decay</th><th style="text-align: right;">  training/lr</th><th style="text-align: right;">  training/n_epochs</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  val_f1</th><th style="text-align: right;">  train_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>ray_tune_sdv_679d5c9b</td><td>RUNNING   </td><td>172.17.88.72:1870627</td><td style="text-align: right;">                   128</td><td style="text-align: right;">           0.65</td><td style="text-align: right;">                     6</td><td style="text-align: right;">                    12</td><td style="text-align: right;">2</td><td style="text-align: right;">                  128</td><td style="text-align: right;">                 4</td><td style="text-align: right;">                  3</td><td style="text-align: right;">256</td><td style="text-align: right;">                   2</td><td style="text-align: right;">     4.41475e-05</td><td style="text-align: right;">  0.00064983 </td><td style="text-align: right;">                 15</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">            </td></tr>
# <tr><td>ray_tune_sdv_90cbd3fa</td><td>PENDING   </td><td>                    </td><td style="text-align: right;">                   128</td><td style="text-align: right;">           0.45</td><td style="text-align: right;">                    12</td><td style="text-align: right;">                     6</td><td style="text-align: right;">2</td><td style="text-align: right;">                   16</td><td style="text-align: right;">                 2</td><td style="text-align: right;">                  2</td><td style="text-align: right;">256</td><td style="text-align: right;">                   2</td><td style="text-align: right;">     0.00861366 </td><td style="text-align: right;">  5.93264e-05</td><td style="text-align: right;">                  5</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">            </td></tr>
# <tr><td>ray_tune_sdv_2753f3f0</td><td>TERMINATED</td><td>172.17.88.72:1870627</td><td style="text-align: right;">                   128</td><td style="text-align: right;">           0.15</td><td style="text-align: right;">                    10</td><td style="text-align: right;">                     4</td><td style="text-align: right;">2</td><td style="text-align: right;">                   16</td><td style="text-align: right;">                 2</td><td style="text-align: right;">                  3</td><td style="text-align: right;"> 32</td><td style="text-align: right;">                   3</td><td style="text-align: right;">     3.48181e-05</td><td style="text-align: right;">  0.000739041</td><td style="text-align: right;">                 10</td><td style="text-align: right;">    11</td><td style="text-align: right;">        332.161 </td><td style="text-align: right;">0.845518</td><td style="text-align: right;">    0.360245</td></tr>
# <tr><td>ray_tune_sdv_bcbd48ff</td><td>TERMINATED</td><td>172.17.88.72:1870627</td><td style="text-align: right;">                   256</td><td style="text-align: right;">           0.2 </td><td style="text-align: right;">                     6</td><td style="text-align: right;">                     8</td><td style="text-align: right;">3</td><td style="text-align: right;">                   32</td><td style="text-align: right;">                 4</td><td style="text-align: right;">                  2</td><td style="text-align: right;">128</td><td style="text-align: right;">                   2</td><td style="text-align: right;">     0.000793064</td><td style="text-align: right;">  3.44379e-05</td><td style="text-align: right;">                 15</td><td style="text-align: right;">     3</td><td style="text-align: right;">         72.4173</td><td style="text-align: right;">0.739009</td><td style="text-align: right;">            </td></tr>
# <tr><td>ray_tune_sdv_52220c6f</td><td>TERMINATED</td><td>172.17.88.72:1870627</td><td style="text-align: right;">                   256</td><td style="text-align: right;">           0.25</td><td style="text-align: right;">                     6</td><td style="text-align: right;">                     6</td><td style="text-align: right;">3</td><td style="text-align: right;">                   32</td><td style="text-align: right;">                 2</td><td style="text-align: right;">                  2</td><td style="text-align: right;"> 64</td><td style="text-align: right;">                   2</td><td style="text-align: right;">     0.00678095 </td><td style="text-align: right;">  7.48425e-05</td><td style="text-align: right;">                 15</td><td style="text-align: right;">     3</td><td style="text-align: right;">         68.1297</td><td style="text-align: right;">0.691893</td><td style="text-align: right;">            </td></tr>
# <tr><td>ray_tune_sdv_ee9f818f</td><td>TERMINATED</td><td>172.17.88.72:1870627</td><td style="text-align: right;">                   128</td><td style="text-align: right;">           0.6 </td><td style="text-align: right;">                     8</td><td style="text-align: right;">                    12</td><td style="text-align: right;">2</td><td style="text-align: right;">                   64</td><td style="text-align: right;">                 3</td><td style="text-align: right;">                  3</td><td style="text-align: right;"> 32</td><td style="text-align: right;">                   2</td><td style="text-align: right;">     0.000119228</td><td style="text-align: right;">  0.00294401 </td><td style="text-align: right;">                 10</td><td style="text-align: right;">    11</td><td style="text-align: right;">        997.158 </td><td style="text-align: right;">0.867695</td><td style="text-align: right;">    0.316711</td></tr>
# <tr><td>ray_tune_sdv_e4cb0611</td><td>TERMINATED</td><td>172.17.88.72:1870627</td><td style="text-align: right;">                    64</td><td style="text-align: right;">           0.1 </td><td style="text-align: right;">                     4</td><td style="text-align: right;">                    10</td><td style="text-align: right;">2</td><td style="text-align: right;">                   64</td><td style="text-align: right;">                 4</td><td style="text-align: right;">
# (ray_tune_sdv pid=1870627) 2024-08-05 18:18:01.061217: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# (ray_tune_sdv pid=1870627) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (ray_tune_sdv pid=1870627) 2024-08-05 18:18:01.205650: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# (ray_tune_sdv pid=1870627) 2024-08-05 18:18:01.655606: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# (ray_tune_sdv pid=1870627) 2024-08-05 18:18:01.655674: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# (ray_tune_sdv pid=1870627) 2024-08-05 18:18:01.655680: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (ray_tune_sdv pid=1870627) Device: 'cuda'
# (ray_tune_sdv pid=1870627) Total Number of Parameters: 871056
# (ray_tune_sdv pid=1870627) Total Number of Trainable Parameters: 871056
# (ray_tune_sdv pid=1870627) Starting training loop at 2024-08-05 18:18:03
# (ray_tune_sdv pid=1870627) MiniBatches:   0%|          | 0/3310 [00:00<?, ?it/s]
# (ray_tune_sdv pid=1870627) Epoch 1
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 1
# (ray_tune_sdv pid=1870627) Epoch time: 31.430431127548218
# (ray_tune_sdv pid=1870627) Train loss: 2.125873408009929
# (ray_tune_sdv pid=1870627) Train accuracy: 0.6868176942007951
# (ray_tune_sdv pid=1870627) Train precision: 0.6857160780377642
# (ray_tune_sdv pid=1870627) Train recall: 0.6897835552470499
# (ray_tune_sdv pid=1870627) Train f1: 0.6877438026928401
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.7365638312303855
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.6971501858118622
# (ray_tune_sdv pid=1870627) Train average_precision: 0.6898785600816781
# (ray_tune_sdv pid=1870627) Val loss: 1.1303895475423855
# (ray_tune_sdv pid=1870627) Val accuracy: 0.6571634105709526
# (ray_tune_sdv pid=1870627) Val precision: 0.5975466466137144
# (ray_tune_sdv pid=1870627) Val recall: 0.9627442071785552
# (ray_tune_sdv pid=1870627) Val f1: 0.737406838152133
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.8921846093849145
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9020784645370765
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9020773585908276
# (ray_tune_sdv pid=1870627) Best val_f1: 0.737406838152133
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 2
# (ray_tune_sdv pid=1870627) Early stopping counter: 1
# (ray_tune_sdv pid=1870627) Epoch Number: 2
# (ray_tune_sdv pid=1870627) Epoch time: 32.08006811141968
# (ray_tune_sdv pid=1870627) Train loss: 0.7169248798201161
# (ray_tune_sdv pid=1870627) Train accuracy: 0.7678424938474159
# (ray_tune_sdv pid=1870627) Train precision: 0.7646032042890094
# (ray_tune_sdv pid=1870627) Train recall: 0.7739635262194737
# (ray_tune_sdv pid=1870627) Train f1: 0.7692548921224285
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.8428988310869723
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.8327159466623388
# (ray_tune_sdv pid=1870627) Train average_precision: 0.8327399031973
# (ray_tune_sdv pid=1870627) Val loss: 0.753196622915386
# (ray_tune_sdv pid=1870627) Val accuracy: 0.7715432379221566
# (ray_tune_sdv pid=1870627) Val precision: 0.9369973190348525
# (ray_tune_sdv pid=1870627) Val recall: 0.5822353475692867
# (ray_tune_sdv pid=1870627) Val f1: 0.718195404446105
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.8962403624995812
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9055488693920077
# (ray_tune_sdv pid=1870627) Val average_precision: 0.905591288692881
# (ray_tune_sdv pid=1870627) Best val_f1: 0.718195404446105
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 3
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 3
# (ray_tune_sdv pid=1870627) Epoch time: 32.09429049491882
# (ray_tune_sdv pid=1870627) Train loss: 0.5483347461108239
# (ray_tune_sdv pid=1870627) Train accuracy: 0.7977219663027703
# (ray_tune_sdv pid=1870627) Train precision: 0.7946172099413014
# (ray_tune_sdv pid=1870627) Train recall: 0.8029911024168612
# (ray_tune_sdv pid=1870627) Train f1: 0.7987822102256678
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.8689249109403268
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.8491120041741744
# (ray_tune_sdv pid=1870627) Train average_precision: 0.8491397678127804
# (ray_tune_sdv pid=1870627) Val loss: 0.5112917912755035
# (ray_tune_sdv pid=1870627) Val accuracy: 0.7955853399969711
# (ray_tune_sdv pid=1870627) Val precision: 0.9042145593869731
# (ray_tune_sdv pid=1870627) Val recall: 0.661214599424504
# (ray_tune_sdv pid=1870627) Val f1: 0.7638542623452739
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.8944881449510247
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.8998780587178583
# (ray_tune_sdv pid=1870627) Val average_precision: 0.8998894536709081
# (ray_tune_sdv pid=1870627) Best val_f1: 0.7638542623452739
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 4
# (ray_tune_sdv pid=1870627) Early stopping counter: 1
# (ray_tune_sdv pid=1870627) Epoch Number: 4
# (ray_tune_sdv pid=1870627) Epoch time: 31.297327518463135
# (ray_tune_sdv pid=1870627) Train loss: 0.43282265432419315
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8204076481352938
# (ray_tune_sdv pid=1870627) Train precision: 0.8231400750970534
# (ray_tune_sdv pid=1870627) Train recall: 0.8161797185587177
# (ray_tune_sdv pid=1870627) Train f1: 0.8196451204055767
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.8952309064758438
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.8774566782749693
# (ray_tune_sdv pid=1870627) Train average_precision: 0.877479568645428
# (ray_tune_sdv pid=1870627) Val loss: 0.9488514985007365
# (ray_tune_sdv pid=1870627) Val accuracy: 0.6374753899742541
# (ray_tune_sdv pid=1870627) Val precision: 0.5815625140392651
# (ray_tune_sdv pid=1870627) Val recall: 0.9802362562471604
# (ray_tune_sdv pid=1870627) Val f1: 0.7300155082475681
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9061304655277987
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9111721800965049
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9111764090319188
# (ray_tune_sdv pid=1870627) Best val_f1: 0.7300155082475681
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 5
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 5
# (ray_tune_sdv pid=1870627) Epoch time: 32.75039482116699
# (ray_tune_sdv pid=1870627) Train loss: 0.44399711057063074
# (ray_tune_sdv pid=1870627) Train accuracy: 0.81854609705307
# (ray_tune_sdv pid=1870627) Train precision: 0.8147524629006111
# (ray_tune_sdv pid=1870627) Train recall: 0.8245724742853537
# (ray_tune_sdv pid=1870627) Train f1: 0.819633056296064
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.8924348496742545
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.8743226392530341
# (ray_tune_sdv pid=1870627) Train average_precision: 0.8743672062839143
# (ray_tune_sdv pid=1870627) Val loss: 0.5207166274748563
# (ray_tune_sdv pid=1870627) Val accuracy: 0.7885809480539149
# (ray_tune_sdv pid=1870627) Val precision: 0.7258771929824561
# (ray_tune_sdv pid=1870627) Val recall: 0.9273814932606391
# (ray_tune_sdv pid=1870627) Val f1: 0.8143493583349956
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9076994618231553
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.913349686935571
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9133537031171163
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8143493583349956
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 6
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 6
# (ray_tune_sdv pid=1870627) Epoch time: 34.25061297416687
# (ray_tune_sdv pid=1870627) Train loss: 0.4706491861612566
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8118886855556257
# (ray_tune_sdv pid=1870627) Train precision: 0.8088483409360745
# (ray_tune_sdv pid=1870627) Train recall: 0.8168107528238784
# (ray_tune_sdv pid=1870627) Train f1: 0.8128100470957614
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.887292324590503
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.8697422374651702
# (ray_tune_sdv pid=1870627) Train average_precision: 0.8697573148006741
# (ray_tune_sdv pid=1870627) Val loss: 0.41405708065643404
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8393533242465546
# (ray_tune_sdv pid=1870627) Val precision: 0.872186695457188
# (ray_tune_sdv pid=1870627) Val recall: 0.7952445857943359
# (ray_tune_sdv pid=1870627) Val f1: 0.8319404285657701
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9092016455927391
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9121407248473616
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9121479275041353
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8319404285657701
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 7
# (ray_tune_sdv pid=1870627) Early stopping counter: 1
# (ray_tune_sdv pid=1870627) Epoch Number: 7
# (ray_tune_sdv pid=1870627) Epoch time: 34.922430992126465
# (ray_tune_sdv pid=1870627) Train loss: 0.3633818202201397
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8475105698239415
# (ray_tune_sdv pid=1870627) Train precision: 0.8376870247731175
# (ray_tune_sdv pid=1870627) Train recall: 0.8620559096358932
# (ray_tune_sdv pid=1870627) Train f1: 0.8496967812159851
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9199789259164457
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.9040333432844394
# (ray_tune_sdv pid=1870627) Train average_precision: 0.9040409523198258
# (ray_tune_sdv pid=1870627) Val loss: 0.4189593996042791
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8313266696955929
# (ray_tune_sdv pid=1870627) Val precision: 0.8957937584803256
# (ray_tune_sdv pid=1870627) Val recall: 0.7498864152657883
# (ray_tune_sdv pid=1870627) Val f1: 0.8163719549894892
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9141963807519466
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9174230139043247
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9174274749457269
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8163719549894892
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 8
# (ray_tune_sdv pid=1870627) Early stopping counter: 2
# (ray_tune_sdv pid=1870627) Epoch Number: 8
# (ray_tune_sdv pid=1870627) Epoch time: 32.40026307106018
# (ray_tune_sdv pid=1870627) Train loss: 0.37268269759032036
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8436928125197198
# (ray_tune_sdv pid=1870627) Train precision: 0.8380609521444975
# (ray_tune_sdv pid=1870627) Train recall: 0.8520224648198397
# (ray_tune_sdv pid=1870627) Train f1: 0.8449840415545403
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9170542770184037
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.8989062062340647
# (ray_tune_sdv pid=1870627) Train average_precision: 0.8989245180162915
# (ray_tune_sdv pid=1870627) Val loss: 0.613421650396453
# (ray_tune_sdv pid=1870627) Val accuracy: 0.7568908072088445
# (ray_tune_sdv pid=1870627) Val precision: 0.9520319786808794
# (ray_tune_sdv pid=1870627) Val recall: 0.5410419506285022
# (ray_tune_sdv pid=1870627) Val f1: 0.6899715127227078
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9168223016633017
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.916413211786672
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9164627480773178
# (ray_tune_sdv pid=1870627) Best val_f1: 0.6899715127227078
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 9
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 9
# (ray_tune_sdv pid=1870627) Epoch time: 32.665345907211304
# (ray_tune_sdv pid=1870627) Train loss: 0.3927683916784102
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8363728150438569
# (ray_tune_sdv pid=1870627) Train precision: 0.8315606145425142
# (ray_tune_sdv pid=1870627) Train recall: 0.8436297090932038
# (ray_tune_sdv pid=1870627) Train f1: 0.8375516852524747
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9111359943191227
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.8898252232316778
# (ray_tune_sdv pid=1870627) Train average_precision: 0.8898523158086495
# (ray_tune_sdv pid=1870627) Val loss: 0.3924512217442195
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8392776010904135
# (ray_tune_sdv pid=1870627) Val precision: 0.8139143838015834
# (ray_tune_sdv pid=1870627) Val recall: 0.8796759048917159
# (ray_tune_sdv pid=1870627) Val f1: 0.8455183958659339
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.914573525762582
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9178698923286976
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9178742878524402
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8455183958659339
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 10
# (ray_tune_sdv pid=1870627) Early stopping counter: 1
# (ray_tune_sdv pid=1870627) Epoch Number: 10
# (ray_tune_sdv pid=1870627) Epoch time: 35.331586599349976
# (ray_tune_sdv pid=1870627) Train loss: 0.36024504347193625
# (ray_tune_sdv pid=1870627) Train accuracy: 0.847131949264845
# (ray_tune_sdv pid=1870627) Train precision: 0.8406191950464397
# (ray_tune_sdv pid=1870627) Train recall: 0.8566921183820282
# (ray_tune_sdv pid=1870627) Train f1: 0.8485795543332187
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9210468499676991
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.9014669337123706
# (ray_tune_sdv pid=1870627) Train average_precision: 0.901475145022977
# (ray_tune_sdv pid=1870627) Val loss: 0.41605862330843285
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8366272906254733
# (ray_tune_sdv pid=1870627) Val precision: 0.900459418070444
# (ray_tune_sdv pid=1870627) Val recall: 0.756928668786915
# (ray_tune_sdv pid=1870627) Val f1: 0.8224791212407947
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9208315405993664
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9226091198559652
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9226135509773796
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8224791212407947
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Training completed!
# (ray_tune_sdv pid=1870627) Device: 'cuda'
# (ray_tune_sdv pid=1870627) Total Number of Parameters: 5521458
# (ray_tune_sdv pid=1870627) Total Number of Trainable Parameters: 5521458
# (ray_tune_sdv pid=1870627) Starting training loop at 2024-08-05 18:23:33
# (ray_tune_sdv pid=1870627) MiniBatches:   0%|          | 0/2805 [00:00<?, ?it/s]
# (ray_tune_sdv pid=1870627) Epoch 1
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 1
# (ray_tune_sdv pid=1870627) Epoch time: 23.536783933639526
# (ray_tune_sdv pid=1870627) Train loss: 1.7448934445898217
# (ray_tune_sdv pid=1870627) Train accuracy: 0.6410317084713677
# (ray_tune_sdv pid=1870627) Train precision: 0.6412590064467197
# (ray_tune_sdv pid=1870627) Train recall: 0.6402271651680076
# (ray_tune_sdv pid=1870627) Train f1: 0.640742670392649
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.6903848687356502
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.620610071643468
# (ray_tune_sdv pid=1870627) Train average_precision: 0.6174716226355967
# (ray_tune_sdv pid=1870627) Val loss: 1.027408046218065
# (ray_tune_sdv pid=1870627) Val accuracy: 0.684764500984401
# (ray_tune_sdv pid=1870627) Val precision: 0.6444812884888679
# (ray_tune_sdv pid=1870627) Val recall: 0.8241708314402544
# (ray_tune_sdv pid=1870627) Val f1: 0.7233335548614342
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.7307957939485192
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.6691642361530299
# (ray_tune_sdv pid=1870627) Val average_precision: 0.6690646280511029
# (ray_tune_sdv pid=1870627) Best val_f1: 0.7233335548614342
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 2
# (ray_tune_sdv pid=1870627) Early stopping counter: 1
# (ray_tune_sdv pid=1870627) Epoch Number: 2
# (ray_tune_sdv pid=1870627) Epoch time: 23.243860721588135
# (ray_tune_sdv pid=1870627) Train loss: 1.0859897201319775
# (ray_tune_sdv pid=1870627) Train accuracy: 0.6682442025556081
# (ray_tune_sdv pid=1870627) Train precision: 0.6753823384311791
# (ray_tune_sdv pid=1870627) Train recall: 0.6478939895882632
# (ray_tune_sdv pid=1870627) Train f1: 0.661352657004831
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.7387404309159108
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.6848938037618356
# (ray_tune_sdv pid=1870627) Train average_precision: 0.6847454798747332
# (ray_tune_sdv pid=1870627) Val loss: 1.0361264113050241
# (ray_tune_sdv pid=1870627) Val accuracy: 0.6144934120854157
# (ray_tune_sdv pid=1870627) Val precision: 0.7432432432432432
# (ray_tune_sdv pid=1870627) Val recall: 0.34984098137210357
# (ray_tune_sdv pid=1870627) Val f1: 0.4757491504479457
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.7595232620090699
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.6993102311142513
# (ray_tune_sdv pid=1870627) Val average_precision: 0.6993275252803282
# (ray_tune_sdv pid=1870627) Best val_f1: 0.4757491504479457
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 3
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 3
# (ray_tune_sdv pid=1870627) Epoch time: 25.409336805343628
# (ray_tune_sdv pid=1870627) Train loss: 0.9661445833114256
# (ray_tune_sdv pid=1870627) Train accuracy: 0.6820870799810695
# (ray_tune_sdv pid=1870627) Train precision: 0.6849492861606499
# (ray_tune_sdv pid=1870627) Train recall: 0.6743492664458116
# (ray_tune_sdv pid=1870627) Train f1: 0.6796079460091098
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.7526300173648401
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.7026852775721774
# (ray_tune_sdv pid=1870627) Train average_precision: 0.7027149200335877
# (ray_tune_sdv pid=1870627) Val loss: 1.1246421180952053
# (ray_tune_sdv pid=1870627) Val accuracy: 0.6648871724973497
# (ray_tune_sdv pid=1870627) Val precision: 0.6051576761481624
# (ray_tune_sdv pid=1870627) Val recall: 0.9488868696047251
# (ray_tune_sdv pid=1870627) Val f1: 0.7390086397546664
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.7915752552964408
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.7459826525983465
# (ray_tune_sdv pid=1870627) Val average_precision: 0.7459956066206246
# (ray_tune_sdv pid=1870627) Best val_f1: 0.7390086397546664
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Device: 'cuda'
# (ray_tune_sdv pid=1870627) Total Number of Parameters: 1937648
# (ray_tune_sdv pid=1870627) Total Number of Trainable Parameters: 1937648
# (ray_tune_sdv pid=1870627) Starting training loop at 2024-08-05 18:24:45
# (ray_tune_sdv pid=1870627) MiniBatches:   0%|          | 0/3120 [00:00<?, ?it/s]
# (ray_tune_sdv pid=1870627) Epoch 1
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 1
# (ray_tune_sdv pid=1870627) Epoch time: 23.389806270599365
# (ray_tune_sdv pid=1870627) Train loss: 1.095884821162774
# (ray_tune_sdv pid=1870627) Train accuracy: 0.678233378767227
# (ray_tune_sdv pid=1870627) Train precision: 0.6721269516252879
# (ray_tune_sdv pid=1870627) Train recall: 0.6959715280932909
# (ray_tune_sdv pid=1870627) Train f1: 0.6838414464016666
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.7174381325873818
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.6505183597453293
# (ray_tune_sdv pid=1870627) Train average_precision: 0.6496439924304287
# (ray_tune_sdv pid=1870627) Val loss: 0.7682491219960726
# (ray_tune_sdv pid=1870627) Val accuracy: 0.6819627442071785
# (ray_tune_sdv pid=1870627) Val precision: 0.6251692884675487
# (ray_tune_sdv pid=1870627) Val recall: 0.9088293200060579
# (ray_tune_sdv pid=1870627) Val f1: 0.740772744105666
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.7644529908513629
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.7146827914390923
# (ray_tune_sdv pid=1870627) Val average_precision: 0.714777597352985
# (ray_tune_sdv pid=1870627) Best val_f1: 0.740772744105666
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 2
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 2
# (ray_tune_sdv pid=1870627) Epoch time: 22.588314294815063
# (ray_tune_sdv pid=1870627) Train loss: 0.5785442584982285
# (ray_tune_sdv pid=1870627) Train accuracy: 0.7506057852491291
# (ray_tune_sdv pid=1870627) Train precision: 0.7279583964733435
# (ray_tune_sdv pid=1870627) Train recall: 0.8002801756777222
# (ray_tune_sdv pid=1870627) Train f1: 0.7624080219304574
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.8097913762254152
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.7587017090360825
# (ray_tune_sdv pid=1870627) Train average_precision: 0.7587317917372569
# (ray_tune_sdv pid=1870627) Val loss: 0.5567093918529841
# (ray_tune_sdv pid=1870627) Val accuracy: 0.739777373920945
# (ray_tune_sdv pid=1870627) Val precision: 0.7161285919049895
# (ray_tune_sdv pid=1870627) Val recall: 0.7944873542329244
# (ray_tune_sdv pid=1870627) Val f1: 0.7532756578238863
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.805111638157122
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.7627193597858335
# (ray_tune_sdv pid=1870627) Val average_precision: 0.7627828638019329
# (ray_tune_sdv pid=1870627) Best val_f1: 0.7532756578238863
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 3
# (ray_tune_sdv pid=1870627) Early stopping counter: 1
# (ray_tune_sdv pid=1870627) Epoch Number: 3
# (ray_tune_sdv pid=1870627) Epoch time: 21.984396934509277
# (ray_tune_sdv pid=1870627) Train loss: 0.5412682031209652
# (ray_tune_sdv pid=1870627) Train accuracy: 0.7586703013781615
# (ray_tune_sdv pid=1870627) Train precision: 0.7353589637591291
# (ray_tune_sdv pid=1870627) Train recall: 0.8081932454944722
# (ray_tune_sdv pid=1870627) Train f1: 0.7700577200577201
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.8230248334910527
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.7847042484687867
# (ray_tune_sdv pid=1870627) Train average_precision: 0.7847491388291009
# (ray_tune_sdv pid=1870627) Val loss: 0.5689299123791548
# (ray_tune_sdv pid=1870627) Val accuracy: 0.7253142510979858
# (ray_tune_sdv pid=1870627) Val precision: 0.7877381297746833
# (ray_tune_sdv pid=1870627) Val recall: 0.6168408299257913
# (ray_tune_sdv pid=1870627) Val f1: 0.6918928101244319
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.8206190392670722
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.7877244039193256
# (ray_tune_sdv pid=1870627) Val average_precision: 0.7877734512498415
# (ray_tune_sdv pid=1870627) Best val_f1: 0.6918928101244319
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Device: 'cuda'
# (ray_tune_sdv pid=1870627) Total Number of Parameters: 3163057
# (ray_tune_sdv pid=1870627) Total Number of Trainable Parameters: 3163057
# (ray_tune_sdv pid=1870627) Starting training loop at 2024-08-05 18:25:54
# (ray_tune_sdv pid=1870627) MiniBatches:   0%|          | 0/7030 [00:00<?, ?it/s]
# (ray_tune_sdv pid=1870627) Epoch 1
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 1
# (ray_tune_sdv pid=1870627) Epoch time: 92.77522540092468
# (ray_tune_sdv pid=1870627) Train loss: 0.7715098607323824
# (ray_tune_sdv pid=1870627) Train accuracy: 0.788302571383499
# (ray_tune_sdv pid=1870627) Train precision: 0.7912476692855663
# (ray_tune_sdv pid=1870627) Train recall: 0.7832465688594415
# (ray_tune_sdv pid=1870627) Train f1: 0.7872267894941296
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.8414242613173891
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.8104283578244522
# (ray_tune_sdv pid=1870627) Train average_precision: 0.809575123153037
# (ray_tune_sdv pid=1870627) Val loss: 0.38233100151382204
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8398076631834015
# (ray_tune_sdv pid=1870627) Val precision: 0.8686437197075495
# (ray_tune_sdv pid=1870627) Val recall: 0.8006966530364985
# (ray_tune_sdv pid=1870627) Val f1: 0.8332873635683044
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9148657760898727
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.91263259116322
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9126426884712329
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8332873635683044
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 2
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 2
# (ray_tune_sdv pid=1870627) Epoch time: 98.0939793586731
# (ray_tune_sdv pid=1870627) Train loss: 0.37686159257446566
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8437292948414576
# (ray_tune_sdv pid=1870627) Train precision: 0.8398371701291409
# (ray_tune_sdv pid=1870627) Train recall: 0.8494557501183152
# (ray_tune_sdv pid=1870627) Train f1: 0.8446190767493296
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9120018421507984
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.9021287211491346
# (ray_tune_sdv pid=1870627) Train average_precision: 0.9021313363993727
# (ray_tune_sdv pid=1870627) Val loss: 0.385513376282609
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8332576101771921
# (ray_tune_sdv pid=1870627) Val precision: 0.7893871646501841
# (ray_tune_sdv pid=1870627) Val recall: 0.9090564894744813
# (ray_tune_sdv pid=1870627) Val f1: 0.8450059829661435
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9226719728151691
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9217824047312272
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9218052945859547
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8450059829661435
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 3
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 3
# (ray_tune_sdv pid=1870627) Epoch time: 96.48293614387512
# (ray_tune_sdv pid=1870627) Train loss: 0.3601135487157491
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8507493295472472
# (ray_tune_sdv pid=1870627) Train precision: 0.8479063654002629
# (ray_tune_sdv pid=1870627) Train recall: 0.8548351474996057
# (ray_tune_sdv pid=1870627) Train f1: 0.8513566591776777
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9194616893331374
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.9102476638032893
# (ray_tune_sdv pid=1870627) Train average_precision: 0.9102493461148453
# (ray_tune_sdv pid=1870627) Val loss: 0.37646000904305543
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8325003786157807
# (ray_tune_sdv pid=1870627) Val precision: 0.7814022045629326
# (ray_tune_sdv pid=1870627) Val recall: 0.9232924428290171
# (ray_tune_sdv pid=1870627) Val f1: 0.8464422075668171
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9285075526709426
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9265104174350607
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9265176240290476
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8464422075668171
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 4
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 4
# (ray_tune_sdv pid=1870627) Epoch time: 100.53200554847717
# (ray_tune_sdv pid=1870627) Train loss: 0.34623173672345375
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8576747120997003
# (ray_tune_sdv pid=1870627) Train precision: 0.8545980606818893
# (ray_tune_sdv pid=1870627) Train recall: 0.8620129357942893
# (ray_tune_sdv pid=1870627) Train f1: 0.8582894840179062
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9256810371003144
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.9160899039413958
# (ray_tune_sdv pid=1870627) Train average_precision: 0.9160930221855056
# (ray_tune_sdv pid=1870627) Val loss: 0.34621020626042776
# (ray_tune_sdv pid=1870627) Val accuracy: 0.849273057701045
# (ray_tune_sdv pid=1870627) Val precision: 0.8246181997325639
# (ray_tune_sdv pid=1870627) Val recall: 0.8872482205058306
# (ray_tune_sdv pid=1870627) Val f1: 0.8547875250775123
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9283897477153981
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.925984337414339
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9259886153295986
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8547875250775123
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 5
# (ray_tune_sdv pid=1870627) Early stopping counter: 1
# (ray_tune_sdv pid=1870627) Epoch Number: 5
# (ray_tune_sdv pid=1870627) Epoch time: 102.0087480545044
# (ray_tune_sdv pid=1870627) Train loss: 0.3411309068962451
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8593705631803124
# (ray_tune_sdv pid=1870627) Train precision: 0.8539158264327994
# (ray_tune_sdv pid=1870627) Train recall: 0.8670768259977915
# (ray_tune_sdv pid=1870627) Train f1: 0.8604460029587421
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9276466873824329
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.9169431230180106
# (ray_tune_sdv pid=1870627) Train average_precision: 0.9169457203974676
# (ray_tune_sdv pid=1870627) Val loss: 0.3627388259206993
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8403755868544601
# (ray_tune_sdv pid=1870627) Val precision: 0.789439793947199
# (ray_tune_sdv pid=1870627) Val recall: 0.928365894290474
# (ray_tune_sdv pid=1870627) Val f1: 0.8532850779510023
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9313012789862406
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.930042554859531
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9300473995049962
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8532850779510023
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 6
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 6
# (ray_tune_sdv pid=1870627) Epoch time: 101.18698024749756
# (ray_tune_sdv pid=1870627) Train loss: 0.3297453304872878
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8644896671399275
# (ray_tune_sdv pid=1870627) Train precision: 0.8581282162564325
# (ray_tune_sdv pid=1870627) Train recall: 0.8733711941946679
# (ray_tune_sdv pid=1870627) Train f1: 0.8656826106672088
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9321985550776659
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.9212744995823229
# (ray_tune_sdv pid=1870627) Train average_precision: 0.9212773933226214
# (ray_tune_sdv pid=1870627) Val loss: 0.33937764520518443
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8537028623353021
# (ray_tune_sdv pid=1870627) Val precision: 0.8271466591959659
# (ray_tune_sdv pid=1870627) Val recall: 0.8942904740269575
# (ray_tune_sdv pid=1870627) Val f1: 0.8594091107553488
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9329089396191603
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9323680180770514
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9323716973818803
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8594091107553488
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 7
# (ray_tune_sdv pid=1870627) Early stopping counter: 1
# (ray_tune_sdv pid=1870627) Epoch Number: 7
# (ray_tune_sdv pid=1870627) Epoch time: 101.6445095539093
# (ray_tune_sdv pid=1870627) Train loss: 0.32675788897059616
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8643082505126992
# (ray_tune_sdv pid=1870627) Train precision: 0.8568382341579492
# (ray_tune_sdv pid=1870627) Train recall: 0.8747752011358259
# (ray_tune_sdv pid=1870627) Train f1: 0.8657138173558041
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9335018953699259
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.9221765914850122
# (ray_tune_sdv pid=1870627) Train average_precision: 0.9221803312916637
# (ray_tune_sdv pid=1870627) Val loss: 0.3557463871396106
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8423822504922005
# (ray_tune_sdv pid=1870627) Val precision: 0.788563405450252
# (ray_tune_sdv pid=1870627) Val recall: 0.9356353172800242
# (ray_tune_sdv pid=1870627) Val f1: 0.8558268398268397
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9362011337074148
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.935785322317098
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9357885739594541
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8558268398268397
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 8
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 8
# (ray_tune_sdv pid=1870627) Epoch time: 98.69712948799133
# (ray_tune_sdv pid=1870627) Train loss: 0.3227291794253453
# (ray_tune_sdv pid=1870627) Train accuracy: 0.86616974286165
# (ray_tune_sdv pid=1870627) Train precision: 0.858417874955606
# (ray_tune_sdv pid=1870627) Train recall: 0.8769837513803439
# (ray_tune_sdv pid=1870627) Train f1: 0.8676015013538717
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9349482686935576
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.9239088108483056
# (ray_tune_sdv pid=1870627) Train average_precision: 0.9239108319910456
# (ray_tune_sdv pid=1870627) Val loss: 0.3228501849560346
# (ray_tune_sdv pid=1870627) Val accuracy: 0.862335302135393
# (ray_tune_sdv pid=1870627) Val precision: 0.8351779209862706
# (ray_tune_sdv pid=1870627) Val recall: 0.9028471906709071
# (ray_tune_sdv pid=1870627) Val f1: 0.8676952186885962
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9385292308470014
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9368990682471894
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9369027762902544
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8676952186885962
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 9
# (ray_tune_sdv pid=1870627) Early stopping counter: 1
# (ray_tune_sdv pid=1870627) Epoch Number: 9
# (ray_tune_sdv pid=1870627) Epoch time: 103.80436825752258
# (ray_tune_sdv pid=1870627) Train loss: 0.32065670459621376
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8657359204921912
# (ray_tune_sdv pid=1870627) Train precision: 0.8565343093531818
# (ray_tune_sdv pid=1870627) Train recall: 0.8786401640637325
# (ray_tune_sdv pid=1870627) Train f1: 0.8674464241216048
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9355997393768363
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.9242442758331734
# (ray_tune_sdv pid=1870627) Train average_precision: 0.9242458067544728
# (ray_tune_sdv pid=1870627) Val loss: 0.35433547846649005
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8429880357413297
# (ray_tune_sdv pid=1870627) Val precision: 0.7879346513254084
# (ray_tune_sdv pid=1870627) Val recall: 0.938588520369529
# (ray_tune_sdv pid=1870627) Val f1: 0.8566886684867125
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9375482730819902
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.9354264603693319
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9354300782099644
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8566886684867125
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 10
# (ray_tune_sdv pid=1870627) Early stopping counter: 2
# (ray_tune_sdv pid=1870627) Epoch Number: 10
# (ray_tune_sdv pid=1870627) Epoch time: 101.73779225349426
# (ray_tune_sdv pid=1870627) Train loss: 0.31671065197236115
# (ray_tune_sdv pid=1870627) Train accuracy: 0.8683625177472788
# (ray_tune_sdv pid=1870627) Train precision: 0.8587362308153201
# (ray_tune_sdv pid=1870627) Train recall: 0.8817794604827259
# (ray_tune_sdv pid=1870627) Train f1: 0.8701053073995376
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.9371019894248107
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.9253986631734035
# (ray_tune_sdv pid=1870627) Train average_precision: 0.9254003840993672
# (ray_tune_sdv pid=1870627) Val loss: 0.32627456070144395
# (ray_tune_sdv pid=1870627) Val accuracy: 0.8648720278661215
# (ray_tune_sdv pid=1870627) Val precision: 0.8661752412797326
# (ray_tune_sdv pid=1870627) Val recall: 0.8630925336968045
# (ray_tune_sdv pid=1870627) Val f1: 0.8646311397686327
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.9368336623156415
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.93500639245841
# (ray_tune_sdv pid=1870627) Val average_precision: 0.9350104440266992
# (ray_tune_sdv pid=1870627) Best val_f1: 0.8646311397686327
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Training completed!
# (ray_tune_sdv pid=1870627) Device: 'cuda'
# (ray_tune_sdv pid=1870627) Total Number of Parameters: 4348178
# (ray_tune_sdv pid=1870627) Total Number of Trainable Parameters: 4348178
# (ray_tune_sdv pid=1870627) Starting training loop at 2024-08-05 18:42:31
# (ray_tune_sdv pid=1870627) MiniBatches:   0%|          | 0/8685 [00:00<?, ?it/s]
# (ray_tune_sdv pid=1870627) Epoch 1
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 1
# (ray_tune_sdv pid=1870627) Epoch time: 77.64064311981201
# (ray_tune_sdv pid=1870627) Train loss: 1.2664031436644405
# (ray_tune_sdv pid=1870627) Train accuracy: 0.7149077141504969
# (ray_tune_sdv pid=1870627) Train precision: 0.7143801340761023
# (ray_tune_sdv pid=1870627) Train recall: 0.7161381921438713
# (ray_tune_sdv pid=1870627) Train f1: 0.7152580828133862
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.7642277080852335
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.7120771041355085
# (ray_tune_sdv pid=1870627) Train average_precision: 0.711010790307864
# (ray_tune_sdv pid=1870627) Val loss: 0.8366113454825076
# (ray_tune_sdv pid=1870627) Val accuracy: 0.7334166288050886
# (ray_tune_sdv pid=1870627) Val precision: 0.802472770091257
# (ray_tune_sdv pid=1870627) Val recall: 0.619263970922308
# (ray_tune_sdv pid=1870627) Val f1: 0.699063982561867
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.8109661946739017
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.7895232238654617
# (ray_tune_sdv pid=1870627) Val average_precision: 0.7895589563305552
# (ray_tune_sdv pid=1870627) Best val_f1: 0.699063982561867
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 2
# (ray_tune_sdv pid=1870627) Early stopping counter: 1
# (ray_tune_sdv pid=1870627) Epoch Number: 2
# (ray_tune_sdv pid=1870627) Epoch time: 77.1559202671051
# (ray_tune_sdv pid=1870627) Train loss: 0.7165628037897938
# (ray_tune_sdv pid=1870627) Train accuracy: 0.7542830099384761
# (ray_tune_sdv pid=1870627) Train precision: 0.7500698129014242
# (ray_tune_sdv pid=1870627) Train recall: 0.7627070515854236
# (ray_tune_sdv pid=1870627) Train f1: 0.756335648582692
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.8190185472081535
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.7850859302161126
# (ray_tune_sdv pid=1870627) Train average_precision: 0.78518288406743
# (ray_tune_sdv pid=1870627) Val loss: 0.8075142535978599
# (ray_tune_sdv pid=1870627) Val accuracy: 0.7041117673784644
# (ray_tune_sdv pid=1870627) Val precision: 0.8812049215103945
# (ray_tune_sdv pid=1870627) Val recall: 0.47183098591549294
# (ray_tune_sdv pid=1870627) Val f1: 0.6145879567983429
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.841965388955667
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.8325808273886134
# (ray_tune_sdv pid=1870627) Val average_precision: 0.8326223200106565
# (ray_tune_sdv pid=1870627) Best val_f1: 0.6145879567983429
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 3
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 3
# (ray_tune_sdv pid=1870627) Epoch time: 78.65633296966553
# (ray_tune_sdv pid=1870627) Train loss: 0.6426766432193388
# (ray_tune_sdv pid=1870627) Train accuracy: 0.7591575958353053
# (ray_tune_sdv pid=1870627) Train precision: 0.755983545250561
# (ray_tune_sdv pid=1870627) Train recall: 0.7653573118788453
# (ray_tune_sdv pid=1870627) Train f1: 0.7606415502563378
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.8256568301741927
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.7961057141845801
# (ray_tune_sdv pid=1870627) Train average_precision: 0.7961635726521796
# (ray_tune_sdv pid=1870627) Val loss: 0.5575704103376329
# (ray_tune_sdv pid=1870627) Val accuracy: 0.7722626079054975
# (ray_tune_sdv pid=1870627) Val precision: 0.7863343155212232
# (ray_tune_sdv pid=1870627) Val recall: 0.747690443737695
# (ray_tune_sdv pid=1870627) Val f1: 0.7665256375422116
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.8384214036185509
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.8295350883784067
# (ray_tune_sdv pid=1870627) Val average_precision: 0.829571353843025
# (ray_tune_sdv pid=1870627) Best val_f1: 0.7665256375422116
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Device: 'cuda'
# (ray_tune_sdv pid=1870627) Total Number of Parameters: 26413680
# (ray_tune_sdv pid=1870627) Total Number of Trainable Parameters: 26413680
# (ray_tune_sdv pid=1870627) Starting training loop at 2024-08-05 18:46:25
# (ray_tune_sdv pid=1870627) MiniBatches:   0%|          | 0/8685 [00:00<?, ?it/s]
# (ray_tune_sdv pid=1870627) Epoch 1
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 1
# (ray_tune_sdv pid=1870627) Epoch time: 152.2698996067047
# (ray_tune_sdv pid=1870627) Train loss: 5.5319094808511835
# (ray_tune_sdv pid=1870627) Train accuracy: 0.6801459761894746
# (ray_tune_sdv pid=1870627) Train precision: 0.6950955602633317
# (ray_tune_sdv pid=1870627) Train recall: 0.6418324849606664
# (ray_tune_sdv pid=1870627) Train f1: 0.6674030249013024
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.7406626125858986
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.7433886789697028
# (ray_tune_sdv pid=1870627) Train average_precision: 0.7006635708541955
# (ray_tune_sdv pid=1870627) Val loss: 1.4747922091884313
# (ray_tune_sdv pid=1870627) Val accuracy: 0.750265031046494
# (ray_tune_sdv pid=1870627) Val precision: 0.8640669751046486
# (ray_tune_sdv pid=1870627) Val recall: 0.5939724367711646
# (ray_tune_sdv pid=1870627) Val f1: 0.704002872015796
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.8438212857596956
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.8299459082451415
# (ray_tune_sdv pid=1870627) Val average_precision: 0.8291832807292862
# (ray_tune_sdv pid=1870627) Best val_f1: 0.704002872015796
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 2
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 2
# (ray_tune_sdv pid=1870627) Epoch time: 161.85420680046082
# (ray_tune_sdv pid=1870627) Train loss: 2.7960401448190852
# (ray_tune_sdv pid=1870627) Train accuracy: 0.7011589752219091
# (ray_tune_sdv pid=1870627) Train precision: 0.7127349571794016
# (ray_tune_sdv pid=1870627) Train recall: 0.6739514534516848
# (ray_tune_sdv pid=1870627) Train f1: 0.6928008475950571
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.7543711098331869
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.7306136897349051
# (ray_tune_sdv pid=1870627) Train average_precision: 0.7121549400593925
# (ray_tune_sdv pid=1870627) Val loss: 1.7491148683480955
# (ray_tune_sdv pid=1870627) Val accuracy: 0.6310389217022565
# (ray_tune_sdv pid=1870627) Val precision: 0.5781158308129825
# (ray_tune_sdv pid=1870627) Val recall: 0.969786460699682
# (ray_tune_sdv pid=1870627) Val f1: 0.7243983144319692
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.8768445377572079
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.8795744927235396
# (ray_tune_sdv pid=1870627) Val average_precision: 0.8795216423641853
# (ray_tune_sdv pid=1870627) Best val_f1: 0.7243983144319692
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Epoch 3
# (ray_tune_sdv pid=1870627) New best model saved!
# (ray_tune_sdv pid=1870627) Epoch Number: 3
# (ray_tune_sdv pid=1870627) Epoch time: 161.56090688705444
# (ray_tune_sdv pid=1870627) Train loss: 1.5385537208408437
# (ray_tune_sdv pid=1870627) Train accuracy: 0.7243805477262211
# (ray_tune_sdv pid=1870627) Train precision: 0.7250384996730165
# (ray_tune_sdv pid=1870627) Train recall: 0.7229186824281688
# (ray_tune_sdv pid=1870627) Train f1: 0.7239770393385645
# (ray_tune_sdv pid=1870627) Train roc_auc: 0.796230960627449
# (ray_tune_sdv pid=1870627) Train pr_auc: 0.7721205788963841
# (ray_tune_sdv pid=1870627) Train average_precision: 0.7689856406018094
# (ray_tune_sdv pid=1870627) Val loss: 1.3594152930997996
# (ray_tune_sdv pid=1870627) Val accuracy: 0.7013100106012419
# (ray_tune_sdv pid=1870627) Val precision: 0.6399726214921286
# (ray_tune_sdv pid=1870627) Val recall: 0.9204149628956535
# (ray_tune_sdv pid=1870627) Val f1: 0.7549923910680456
# (ray_tune_sdv pid=1870627) Val roc_auc: 0.8672863958481829
# (ray_tune_sdv pid=1870627) Val pr_auc: 0.8686430478107673
# (ray_tune_sdv pid=1870627) Val average_precision: 0.8679579795210193
# (ray_tune_sdv pid=1870627) Best val_f1: 0.7549923910680456
# (ray_tune_sdv pid=1870627)
# (ray_tune_sdv pid=1870627) Device: 'cuda'
# (ray_tune_sdv pid=1870627) Total Number of Parameters: 33765490
# (ray_tune_sdv pid=1870627) Total Number of Trainable Parameters: 33765490
# (ray_tune_sdv pid=1870627) Starting training loop at 2024-08-05 18:54:21
# (ray_tune_sdv pid=1870627) MiniBatches:   0%|          | 0/11160 [00:00<?, ?it/s]
# (ray_tune_sdv pid=1870627) Epoch 1

# %%
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-08-05 10:30:17</td></tr>
# <tr><td>Running for: </td><td>09:43:17.14        </td></tr>
# <tr><td>Memory:      </td><td>11.3/19.4 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=13<br>Bracket: Iter 16.000: 0.8620859360212001 | Iter 4.000: 0.8554066196631529<br>Logical resource usage: 4.0/4 CPUs, 1.0/1 GPUs
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 7<br><table>
# <thead>
# <tr><th>Trial name           </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                                                             </th></tr>
# </thead>
# <tbody>
# <tr><td>ray_tune_sdv_1d2160e6</td><td style="text-align: right;">           1</td><td>/root/SDV-HGNN/hyperparam/ray_results/ray_tune_sdv_2024-08-05_00-46-59/ray_tune_sdv_1d2160e6_1_batch_size=128,dtr=0.1500,num_neigh1=10,num_neigh2=6,mol_block_param=3,mol_heads_out=16,mol_n_head=2,outer_2024-08-05_00-47-00/error.txt</td></tr>
# <tr><td>ray_tune_sdv_f5b47831</td><td style="text-align: right;">           1</td><td>/root/SDV-HGNN/hyperparam/ray_results/ray_tune_sdv_2024-08-05_00-46-59/ray_tune_sdv_f5b47831_2_batch_size=128,dtr=0.5500,num_neigh1=8,num_neigh2=12,mol_block_param=2,mol_heads_out=64,mol_n_head=2,outer_2024-08-05_00-47-02/error.txt</td></tr>
# <tr><td>ray_tune_sdv_1d96640c</td><td style="text-align: right;">           1</td><td>/root/SDV-HGNN/hyperparam/ray_results/ray_tune_sdv_2024-08-05_00-46-59/ray_tune_sdv_1d96640c_3_batch_size=128,dtr=0.3500,num_neigh1=12,num_neigh2=6,mol_block_param=3,mol_heads_out=32,mol_n_head=3,outer_2024-08-05_00-58-53/error.txt</td></tr>
# <tr><td>ray_tune_sdv_afbfd312</td><td style="text-align: right;">           1</td><td>/root/SDV-HGNN/hyperparam/ray_results/ray_tune_sdv_2024-08-05_00-46-59/ray_tune_sdv_afbfd312_6_batch_size=32,dtr=0.5000,num_neigh1=12,num_neigh2=10,mol_block_param=1,mol_heads_out=16,mol_n_head=3,outer_2024-08-05_02-03-25/error.txt</td></tr>
# <tr><td>ray_tune_sdv_796b45b0</td><td style="text-align: right;">           1</td><td>/root/SDV-HGNN/hyperparam/ray_results/ray_tune_sdv_2024-08-05_00-46-59/ray_tune_sdv_796b45b0_8_batch_size=16,dtr=0.5500,num_neigh1=12,num_neigh2=4,mol_block_param=2,mol_heads_out=32,mol_n_head=2,outer__2024-08-05_03-13-49/error.txt</td></tr>
# <tr><td>ray_tune_sdv_2c093bc7</td><td style="text-align: right;">           1</td><td>/root/SDV-HGNN/hyperparam/ray_results/ray_tune_sdv_2024-08-05_00-46-59/ray_tune_sdv_2c093bc7_12_batch_size=64,dtr=0.3500,num_neigh1=8,num_neigh2=10,mol_block_param=2,mol_heads_out=32,mol_n_head=4,outer_2024-08-05_04-44-15/error.txt</td></tr>
# <tr><td>ray_tune_sdv_67363dff</td><td style="text-align: right;">           1</td><td>/root/SDV-HGNN/hyperparam/ray_results/ray_tune_sdv_2024-08-05_00-46-59/ray_tune_sdv_67363dff_19_batch_size=16,dtr=0.5000,num_neigh1=8,num_neigh2=10,mol_block_param=2,mol_heads_out=128,mol_n_head=2,oute_2024-08-05_06-22-51/error.txt</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc                 </th><th style="text-align: right;">  load_data/batch_size</th><th style="text-align: right;">  load_data/dtr</th><th style="text-align: right;">  load_data/num_neigh1</th><th style="text-align: right;">  load_data/num_neigh2</th><th style="text-align: right;">  model/mol_block_para
# m</th><th style="text-align: right;">  model/mol_heads_out</th><th style="text-align: right;">  model/mol_n_head</th><th style="text-align: right;">  model/outer_block</th><th style="text-align: right;">    model/outer_hidden_d
# ims</th><th style="text-align: right;">  model/outer_n_head</th><th style="text-align: right;">  training/decay</th><th style="text-align: right;">  training/lr</th><th style="text-align: right;">  training/n_epochs</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  val_f1</th></tr>
# </thead>
# <tbody>
# <tr><td>ray_tune_sdv_44b6dbab</td><td>RUNNING   </td><td>172.17.88.72:1043506</td><td style="text-align: right;">                    16</td><td style="text-align: right;">           0.5 </td><td style="text-align: right;">                     6</td><td style="text-align: right;">                    10</td><td style="text-align: right;">2</td><td style="text-align: right;">                  128</td><td style="text-align: right;">                 4</td><td style="text-align: right;">                  1</td><td style="text-align: right;"> 64</td><td style="text-align: right;">                   3</td><td style="text-align: right;">     9.25228e-05</td><td style="text-align: right;">  0.000119418</td><td style="text-align: right;">                 10</td><td style="text-align: right;">     3</td><td style="text-align: right;">       2757.28  </td><td style="text-align: right;">0.854303</td></tr>
# <tr><td>ray_tune_sdv_b1763bdc</td><td>PENDING   </td><td>                    </td><td style="text-align: right;">                    16</td><td style="text-align: right;">           0.45</td><td style="text-align: right;">                    10</td><td style="text-align: right;">                    10</td><td style="text-align: right;">2</td><td style="text-align: right;">                  128</td><td style="text-align: right;">                 4</td><td style="text-align: right;">                  1</td><td style="text-align: right;"> 64</td><td style="text-align: right;">                   3</td><td style="text-align: right;">     0.000154732</td><td style="text-align: right;">  6.65609e-05</td><td style="text-align: right;">                 15</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td></tr>
# <tr><td>ray_tune_sdv_60a4baa2</td><td>TERMINATED</td><td>172.17.88.72:243144 </td><td style="text-align: right;">                    16</td><td style="text-align: right;">           0.35</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     8</td><td style="text-align: right;">1</td><td style="text-align: right;">                   32</td><td style="text-align: right;">                 2</td><td style="text-align: right;">                  1</td><td style="text-align: right;">128</td><td style="text-align: right;">                   1</td><td style="text-align: right;">     0.00831433 </td><td style="text-align: right;">  0.000110584</td><td style="text-align: right;">                 20</td><td style="text-align: right;">     4</td><td style="text-align: right;">       1220.78  </td><td style="text-align: right;">0.746451</td></tr>
# <tr><td>ray_tune_sdv_eaed376e</td><td>TERMINATED</td><td>172.17.88.72:243144 </td><td style="text-align: right;">                   256</td><td style="text-align: right;">           0.35</td><td style="text-align: right;">                    10</td><td style="text-align: right;">                     8</td><td style="text-align: right;">2</td><td style="text-align: right;">
# (ray_tune_sdv pid=85167) 2024-08-05 00:47:02.824066: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# (ray_tune_sdv pid=85167) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (ray_tune_sdv pid=85167) 2024-08-05 00:47:02.931750: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# (ray_tune_sdv pid=85167) 2024-08-05 00:47:03.353484: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# (ray_tune_sdv pid=85167) 2024-08-05 00:47:03.353530: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# (ray_tune_sdv pid=85167) 2024-08-05 00:47:03.353534: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (ray_tune_sdv pid=85167) Device: 'cuda'
# (ray_tune_sdv pid=85167) Total Number of Parameters: 12081200
# (ray_tune_sdv pid=85167) Total Number of Trainable Parameters: 12081200
# (ray_tune_sdv pid=85167) Starting training loop at 2024-08-05 00:47:05
# (ray_tune_sdv pid=85167) MiniBatches:   0%|          | 0/4965 [00:00<?, ?it/s]
# (ray_tune_sdv pid=85167) Epoch 1
# (ray_tune_sdv pid=85167) New best model saved!
# (ray_tune_sdv pid=85167) Epoch Number: 1
# (ray_tune_sdv pid=85167) Epoch time: 42.505014419555664
# (ray_tune_sdv pid=85167) Train loss: 8.557623839186084
# (ray_tune_sdv pid=85167) Train accuracy: 0.6499021896889001
# (ray_tune_sdv pid=85167) Train precision: 0.6549474920096536
# (ray_tune_sdv pid=85167) Train recall: 0.6336215056477567
# (ray_tune_sdv pid=85167) Train f1: 0.644108024889345
# (ray_tune_sdv pid=85167) Train roc_auc: 0.7000606632309101
# (ray_tune_sdv pid=85167) Train pr_auc: 0.7177883126879698
# (ray_tune_sdv pid=85167) Train average_precision: 0.6708453017903896
# (ray_tune_sdv pid=85167) Val loss: 4.0665928600083925
# (ray_tune_sdv pid=85167) Val accuracy: 0.5081402392851734
# (ray_tune_sdv pid=85167) Val precision: 0.7707808564231738
# (ray_tune_sdv pid=85167) Val recall: 0.023171285779191277
# (ray_tune_sdv pid=85167) Val f1: 0.04499007571859149
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8326098807445728
# (ray_tune_sdv pid=85167) Val pr_auc: 0.8041324467346666
# (ray_tune_sdv pid=85167) Val average_precision: 0.8041991273535399
# (ray_tune_sdv pid=85167) Best val_f1: 0.04499007571859149
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 2
# (ray_tune_sdv pid=85167) New best model saved!
# (ray_tune_sdv pid=85167) Epoch Number: 2
# (ray_tune_sdv pid=85167) Epoch time: 41.30737018585205
# (ray_tune_sdv pid=85167) Train loss: 4.118847319195347
# (ray_tune_sdv pid=85167) Train accuracy: 0.6409415031236196
# (ray_tune_sdv pid=85167) Train precision: 0.653811720955857
# (ray_tune_sdv pid=85167) Train recall: 0.599103931343472
# (ray_tune_sdv pid=85167) Train f1: 0.6252634351949421
# (ray_tune_sdv pid=85167) Train roc_auc: 0.7145318315293891
# (ray_tune_sdv pid=85167) Train pr_auc: 0.7181489528207377
# (ray_tune_sdv pid=85167) Train average_precision: 0.6856581155303267
# (ray_tune_sdv pid=85167) Val loss: 1.8832053733170753
# (ray_tune_sdv pid=85167) Val accuracy: 0.776124488868696
# (ray_tune_sdv pid=85167) Val precision: 0.9522510231923602
# (ray_tune_sdv pid=85167) Val recall: 0.581402392851734
# (ray_tune_sdv pid=85167) Val f1: 0.7219897503408716
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8803199444976675
# (ray_tune_sdv pid=85167) Val pr_auc: 0.8862764262539037
# (ray_tune_sdv pid=85167) Val average_precision: 0.8862899021626195
# (ray_tune_sdv pid=85167) Best val_f1: 0.7219897503408716
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 3
# (ray_tune_sdv pid=85167) Early stopping counter: 1
# (ray_tune_sdv pid=85167) Epoch Number: 3
# (ray_tune_sdv pid=85167) Epoch time: 44.8590350151062
# (ray_tune_sdv pid=85167) Train loss: 2.6617931545742097
# (ray_tune_sdv pid=85167) Train accuracy: 0.6643528743610778
# (ray_tune_sdv pid=85167) Train precision: 0.6599717462072354
# (ray_tune_sdv pid=85167) Train recall: 0.6780463179150628
# (ray_tune_sdv pid=85167) Train f1: 0.6688869521912351
# (ray_tune_sdv pid=85167) Train roc_auc: 0.7482787452324648
# (ray_tune_sdv pid=85167) Train pr_auc: 0.7461311472982837
# (ray_tune_sdv pid=85167) Train average_precision: 0.724537204355479
# (ray_tune_sdv pid=85167) Val loss: 1.6099468682384217
# (ray_tune_sdv pid=85167) Val accuracy: 0.6863925488414357
# (ray_tune_sdv pid=85167) Val precision: 0.9304074138835461
# (ray_tune_sdv pid=85167) Val recall: 0.4029229138270483
# (ray_tune_sdv pid=85167) Val f1: 0.562324966974901
# (ray_tune_sdv pid=85167) Val roc_auc: 0.86455161501563
# (ray_tune_sdv pid=85167) Val pr_auc: 0.8653931525000214
# (ray_tune_sdv pid=85167) Val average_precision: 0.8654340457200375
# (ray_tune_sdv pid=85167) Best val_f1: 0.7219897503408716
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 4
# (ray_tune_sdv pid=85167) New best model saved!
# (ray_tune_sdv pid=85167) Epoch Number: 4
# (ray_tune_sdv pid=85167) Epoch time: 46.34568691253662
# (ray_tune_sdv pid=85167) Train loss: 3.0499054380962924
# (ray_tune_sdv pid=85167) Train accuracy: 0.648797879724869
# (ray_tune_sdv pid=85167) Train precision: 0.6542991755005889
# (ray_tune_sdv pid=85167) Train recall: 0.6309711617340822
# (ray_tune_sdv pid=85167) Train f1: 0.6424234636512577
# (ray_tune_sdv pid=85167) Train roc_auc: 0.70682307123234
# (ray_tune_sdv pid=85167) Train pr_auc: 0.6880907717105413
# (ray_tune_sdv pid=85167) Train average_precision: 0.6661427147068574
# (ray_tune_sdv pid=85167) Val loss: 0.8221485463605411
# (ray_tune_sdv pid=85167) Val accuracy: 0.709828865667121
# (ray_tune_sdv pid=85167) Val precision: 0.6773099564883542
# (ray_tune_sdv pid=85167) Val recall: 0.8015296077540512
# (ray_tune_sdv pid=85167) Val f1: 0.7342026773947423
# (ray_tune_sdv pid=85167) Val roc_auc: 0.7747539977938793
# (ray_tune_sdv pid=85167) Val pr_auc: 0.7682403447868957
# (ray_tune_sdv pid=85167) Val average_precision: 0.7683170513613096
# (ray_tune_sdv pid=85167) Best val_f1: 0.7342026773947423
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 5
# (ray_tune_sdv pid=85167) Early stopping counter: 1
# (ray_tune_sdv pid=85167) Epoch Number: 5
# (ray_tune_sdv pid=85167) Epoch time: 46.57669425010681
# (ray_tune_sdv pid=85167) Train loss: 1.793138118040177
# (ray_tune_sdv pid=85167) Train accuracy: 0.6461159840979365
# (ray_tune_sdv pid=85167) Train precision: 0.6508763927803479
# (ray_tune_sdv pid=85167) Train recall: 0.6303401274689215
# (ray_tune_sdv pid=85167) Train f1: 0.6404436750657178
# (ray_tune_sdv pid=85167) Train roc_auc: 0.6988479839729482
# (ray_tune_sdv pid=85167) Train pr_auc: 0.6669419251853709
# (ray_tune_sdv pid=85167) Train average_precision: 0.6647167383545532
# (ray_tune_sdv pid=85167) Val loss: 0.7842937628716087
# (ray_tune_sdv pid=85167) Val accuracy: 0.6948735423292443
# (ray_tune_sdv pid=85167) Val precision: 0.7369923565705866
# (ray_tune_sdv pid=85167) Val recall: 0.6060124185976071
# (ray_tune_sdv pid=85167) Val f1: 0.665115312694785
# (ray_tune_sdv pid=85167) Val roc_auc: 0.7436754364012759
# (ray_tune_sdv pid=85167) Val pr_auc: 0.7166485429985108
# (ray_tune_sdv pid=85167) Val average_precision: 0.7167305343458386
# (ray_tune_sdv pid=85167) Best val_f1: 0.7342026773947423
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 6
# (ray_tune_sdv pid=85167) New best model saved!
# (ray_tune_sdv pid=85167) Epoch Number: 6
# (ray_tune_sdv pid=85167) Epoch time: 47.18139100074768
# (ray_tune_sdv pid=85167) Train loss: 1.1524325090069925
# (ray_tune_sdv pid=85167) Train accuracy: 0.6831576954628636
# (ray_tune_sdv pid=85167) Train precision: 0.6909916430874514
# (ray_tune_sdv pid=85167) Train recall: 0.6626490818451442
# (ray_tune_sdv pid=85167) Train f1: 0.6765236438603272
# (ray_tune_sdv pid=85167) Train roc_auc: 0.7417768723126515
# (ray_tune_sdv pid=85167) Train pr_auc: 0.7011601754553862
# (ray_tune_sdv pid=85167) Train average_precision: 0.7010814927039722
# (ray_tune_sdv pid=85167) Val loss: 0.5484256434123873
# (ray_tune_sdv pid=85167) Val accuracy: 0.7791912766924125
# (ray_tune_sdv pid=85167) Val precision: 0.8695870088211708
# (ray_tune_sdv pid=85167) Val recall: 0.6568983795244586
# (ray_tune_sdv pid=85167) Val f1: 0.748425502545078
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8446670645601433
# (ray_tune_sdv pid=85167) Val pr_auc: 0.8276386429279876
# (ray_tune_sdv pid=85167) Val average_precision: 0.8277250044471238
# (ray_tune_sdv pid=85167) Best val_f1: 0.748425502545078
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 7
# (ray_tune_sdv pid=85167) Early stopping counter: 1
# (ray_tune_sdv pid=85167) Epoch Number: 7
# (ray_tune_sdv pid=85167) Epoch time: 47.117608308792114
# (ray_tune_sdv pid=85167) Train loss: 1.304815128205284
# (ray_tune_sdv pid=85167) Train accuracy: 0.652868050735155
# (ray_tune_sdv pid=85167) Train precision: 0.6527523803518507
# (ray_tune_sdv pid=85167) Train recall: 0.6532466712942513
# (ray_tune_sdv pid=85167) Train f1: 0.6529994322841103
# (ray_tune_sdv pid=85167) Train roc_auc: 0.7158156539575495
# (ray_tune_sdv pid=85167) Train pr_auc: 0.6887987417260942
# (ray_tune_sdv pid=85167) Train average_precision: 0.688773368282471
# (ray_tune_sdv pid=85167) Val loss: 0.7292316086986215
# (ray_tune_sdv pid=85167) Val accuracy: 0.752044525215811
# (ray_tune_sdv pid=85167) Val precision: 0.9649392373236485
# (ray_tune_sdv pid=85167) Val recall: 0.5230955626230501
# (ray_tune_sdv pid=85167) Val f1: 0.6784188558801867
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8837928770186907
# (ray_tune_sdv pid=85167) Val pr_auc: 0.8931047870169027
# (ray_tune_sdv pid=85167) Val average_precision: 0.8931257939014249
# (ray_tune_sdv pid=85167) Best val_f1: 0.748425502545078
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 8
# (ray_tune_sdv pid=85167) New best model saved!
# (ray_tune_sdv pid=85167) Epoch Number: 8
# (ray_tune_sdv pid=85167) Epoch time: 48.50597381591797
# (ray_tune_sdv pid=85167) Train loss: 1.2180829487981335
# (ray_tune_sdv pid=85167) Train accuracy: 0.6597778759386634
# (ray_tune_sdv pid=85167) Train precision: 0.6593856225607453
# (ray_tune_sdv pid=85167) Train recall: 0.6610083927557266
# (ray_tune_sdv pid=85167) Train f1: 0.6601960104622948
# (ray_tune_sdv pid=85167) Train roc_auc: 0.7367732050307579
# (ray_tune_sdv pid=85167) Train pr_auc: 0.7223841157731508
# (ray_tune_sdv pid=85167) Train average_precision: 0.7224592501379226
# (ray_tune_sdv pid=85167) Val loss: 0.54047666673643
# (ray_tune_sdv pid=85167) Val accuracy: 0.7893381796153264
# (ray_tune_sdv pid=85167) Val precision: 0.8415876989093509
# (ray_tune_sdv pid=85167) Val recall: 0.7128577919127669
# (ray_tune_sdv pid=85167) Val f1: 0.7718924237454903
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8499346662718925
# (ray_tune_sdv pid=85167) Val pr_auc: 0.8084241506120455
# (ray_tune_sdv pid=85167) Val average_precision: 0.808487561741369
# (ray_tune_sdv pid=85167) Best val_f1: 0.7718924237454903
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 9
# (ray_tune_sdv pid=85167) Early stopping counter: 1
# (ray_tune_sdv pid=85167) Epoch Number: 9
# (ray_tune_sdv pid=85167) Epoch time: 49.27171468734741
# (ray_tune_sdv pid=85167) Train loss: 0.9816407061392262
# (ray_tune_sdv pid=85167) Train accuracy: 0.678204076481353
# (ray_tune_sdv pid=85167) Train precision: 0.6905790255095154
# (ray_tune_sdv pid=85167) Train recall: 0.6457373635388401
# (ray_tune_sdv pid=85167) Train f1: 0.6674058372737649
# (ray_tune_sdv pid=85167) Train roc_auc: 0.7425097015196775
# (ray_tune_sdv pid=85167) Train pr_auc: 0.7197210784664945
# (ray_tune_sdv pid=85167) Train average_precision: 0.7198002450407004
# (ray_tune_sdv pid=85167) Val loss: 0.6913990774304395
# (ray_tune_sdv pid=85167) Val accuracy: 0.7174011812812358
# (ray_tune_sdv pid=85167) Val precision: 0.6581643895989423
# (ray_tune_sdv pid=85167) Val recall: 0.9046645464182947
# (ray_tune_sdv pid=85167) Val f1: 0.7619746157280438
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8823748310449299
# (ray_tune_sdv pid=85167) Val pr_auc: 0.8984304351312573
# (ray_tune_sdv pid=85167) Val average_precision: 0.8984458679968736
# (ray_tune_sdv pid=85167) Best val_f1: 0.7718924237454903
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 10
# (ray_tune_sdv pid=85167) New best model saved!
# (ray_tune_sdv pid=85167) Epoch Number: 10
# (ray_tune_sdv pid=85167) Epoch time: 47.59151482582092
# (ray_tune_sdv pid=85167) Train loss: 0.7743199318647385
# (ray_tune_sdv pid=85167) Train accuracy: 0.7143623398750553
# (ray_tune_sdv pid=85167) Train precision: 0.6981220109646564
# (ray_tune_sdv pid=85167) Train recall: 0.7553480153972361
# (ray_tune_sdv pid=85167) Train f1: 0.7256084624011153
# (ray_tune_sdv pid=85167) Train roc_auc: 0.7845497183463555
# (ray_tune_sdv pid=85167) Train pr_auc: 0.7661518366714721
# (ray_tune_sdv pid=85167) Train average_precision: 0.7662093111189265
# (ray_tune_sdv pid=85167) Val loss: 0.428082960959218
# (ray_tune_sdv pid=85167) Val accuracy: 0.8087611691655309
# (ray_tune_sdv pid=85167) Val precision: 0.7931976702380097
# (ray_tune_sdv pid=85167) Val recall: 0.8353021353930031
# (ray_tune_sdv pid=85167) Val f1: 0.813705602478516
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8911999359902517
# (ray_tune_sdv pid=85167) Val pr_auc: 0.9019443252803575
# (ray_tune_sdv pid=85167) Val average_precision: 0.9019606226047169
# (ray_tune_sdv pid=85167) Best val_f1: 0.813705602478516
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 11
# (ray_tune_sdv pid=85167) Early stopping counter: 1
# (ray_tune_sdv pid=85167) Epoch Number: 11
# (ray_tune_sdv pid=85167) Epoch time: 47.42408585548401
# (ray_tune_sdv pid=85167) Train loss: 0.6501131293273741
# (ray_tune_sdv pid=85167) Train accuracy: 0.7419700889758314
# (ray_tune_sdv pid=85167) Train precision: 0.7388947729113451
# (ray_tune_sdv pid=85167) Train recall: 0.7484066384804695
# (ray_tune_sdv pid=85167) Train f1: 0.7436202896733338
# (ray_tune_sdv pid=85167) Train roc_auc: 0.804035397028287
# (ray_tune_sdv pid=85167) Train pr_auc: 0.7771649854963947
# (ray_tune_sdv pid=85167) Train average_precision: 0.7772237244669714
# (ray_tune_sdv pid=85167) Val loss: 0.535607921184549
# (ray_tune_sdv pid=85167) Val accuracy: 0.793730122671513
# (ray_tune_sdv pid=85167) Val precision: 0.7741342756183746
# (ray_tune_sdv pid=85167) Val recall: 0.8294714523701348
# (ray_tune_sdv pid=85167) Val f1: 0.8008480772042695
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8702857260715342
# (ray_tune_sdv pid=85167) Val pr_auc: 0.8758576271528813
# (ray_tune_sdv pid=85167) Val average_precision: 0.8758991656581381
# (ray_tune_sdv pid=85167) Best val_f1: 0.813705602478516
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 12
# (ray_tune_sdv pid=85167) Early stopping counter: 2
# (ray_tune_sdv pid=85167) Epoch Number: 12
# (ray_tune_sdv pid=85167) Epoch time: 48.24601364135742
# (ray_tune_sdv pid=85167) Train loss: 0.6988103735831476
# (ray_tune_sdv pid=85167) Train accuracy: 0.7272354388843314
# (ray_tune_sdv pid=85167) Train precision: 0.7191455696202531
# (ray_tune_sdv pid=85167) Train recall: 0.7456931911402789
# (ray_tune_sdv pid=85167) Train f1: 0.7321788159484494
# (ray_tune_sdv pid=85167) Train roc_auc: 0.7965015320171602
# (ray_tune_sdv pid=85167) Train pr_auc: 0.7755451169049825
# (ray_tune_sdv pid=85167) Train average_precision: 0.7756022667874077
# (ray_tune_sdv pid=85167) Val loss: 0.7076935765967853
# (ray_tune_sdv pid=85167) Val accuracy: 0.7490913221263062
# (ray_tune_sdv pid=85167) Val precision: 0.6926952141057935
# (ray_tune_sdv pid=85167) Val recall: 0.8954263213690746
# (ray_tune_sdv pid=85167) Val f1: 0.7811209829243321
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8811527443973178
# (ray_tune_sdv pid=85167) Val pr_auc: 0.8905949126044167
# (ray_tune_sdv pid=85167) Val average_precision: 0.8906068625858502
# (ray_tune_sdv pid=85167) Best val_f1: 0.813705602478516
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 13
# (ray_tune_sdv pid=85167) New best model saved!
# (ray_tune_sdv pid=85167) Epoch Number: 13
# (ray_tune_sdv pid=85167) Epoch time: 49.59060263633728
# (ray_tune_sdv pid=85167) Train loss: 0.6952781331154608
# (ray_tune_sdv pid=85167) Train accuracy: 0.7337035401022276
# (ray_tune_sdv pid=85167) Train precision: 0.7285405738969454
# (ray_tune_sdv pid=85167) Train recall: 0.7449990534486023
# (ray_tune_sdv pid=85167) Train f1: 0.7366778984150755
# (ray_tune_sdv pid=85167) Train roc_auc: 0.7884154712080831
# (ray_tune_sdv pid=85167) Train pr_auc: 0.7492826928452984
# (ray_tune_sdv pid=85167) Train average_precision: 0.7493470437644991
# (ray_tune_sdv pid=85167) Val loss: 0.4282264045039237
# (ray_tune_sdv pid=85167) Val accuracy: 0.8106921096471301
# (ray_tune_sdv pid=85167) Val precision: 0.7986606492939292
# (ray_tune_sdv pid=85167) Val recall: 0.8308344691806755
# (ray_tune_sdv pid=85167) Val f1: 0.8144299287410927
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8910604651294005
# (ray_tune_sdv pid=85167) Val pr_auc: 0.9014275354779977
# (ray_tune_sdv pid=85167) Val average_precision: 0.9014612377953923
# (ray_tune_sdv pid=85167) Best val_f1: 0.8144299287410927
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 14
# (ray_tune_sdv pid=85167) Early stopping counter: 1
# (ray_tune_sdv pid=85167) Epoch Number: 14
# (ray_tune_sdv pid=85167) Epoch time: 48.25404906272888
# (ray_tune_sdv pid=85167) Train loss: 0.5774468133045781
# (ray_tune_sdv pid=85167) Train accuracy: 0.7725436991228624
# (ray_tune_sdv pid=85167) Train precision: 0.7659810321468161
# (ray_tune_sdv pid=85167) Train recall: 0.7848804190067521
# (ray_tune_sdv pid=85167) Train f1: 0.7753155680224404
# (ray_tune_sdv pid=85167) Train roc_auc: 0.8221376006790242
# (ray_tune_sdv pid=85167) Train pr_auc: 0.8049862530810408
# (ray_tune_sdv pid=85167) Train average_precision: 0.8050382461317451
# (ray_tune_sdv pid=85167) Val loss: 0.7894285806783156
# (ray_tune_sdv pid=85167) Val accuracy: 0.6485309707708617
# (ray_tune_sdv pid=85167) Val precision: 0.5943255590286126
# (ray_tune_sdv pid=85167) Val recall: 0.9358624867484476
# (ray_tune_sdv pid=85167) Val f1: 0.7269786182759329
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8748240723901904
# (ray_tune_sdv pid=85167) Val pr_auc: 0.887741892766849
# (ray_tune_sdv pid=85167) Val average_precision: 0.8878003322447482
# (ray_tune_sdv pid=85167) Best val_f1: 0.8144299287410927
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Epoch 15
# 2024-08-05 00:58:49,482	ERROR tune_controller.py:1502 -- Trial task failed for trial ray_tune_sdv_1d2160e6
# Traceback (most recent call last):
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/_private/worker.py", line 2547, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=85167, ip=172.17.88.72, actor_id=9c68c0fda2d2ee05cafa7ebe01000000, repr=ray_tune_sdv)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/tune/trainable/trainable.py", line 400, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/air/_internal/util.py", line 91, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/tune/trainable/function_trainable.py", line 383, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/tune/trainable/function_trainable.py", line 823, in _trainable_func
#     handle_output(output)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/tune/trainable/function_trainable.py", line 812, in handle_output
#     "Invalid return or yield value. Either return/yield "
# ValueError: Invalid return or yield value. Either return/yield a single number or a dictionary object in your trainable function.
# (ray_tune_sdv pid=85167) Early stopping counter: 2
# (ray_tune_sdv pid=85167) Epoch Number: 15
# (ray_tune_sdv pid=85167) Epoch time: 48.68236684799194
# (ray_tune_sdv pid=85167) Train loss: 0.8214024605770265
# (ray_tune_sdv pid=85167) Train accuracy: 0.6783618350476431
# (ray_tune_sdv pid=85167) Train precision: 0.6832890214642371
# (ray_tune_sdv pid=85167) Train recall: 0.6649208051997223
# (ray_tune_sdv pid=85167) Train f1: 0.673979787642318
# (ray_tune_sdv pid=85167) Train roc_auc: 0.7461999319237989
# (ray_tune_sdv pid=85167) Train pr_auc: 0.7289931525285591
# (ray_tune_sdv pid=85167) Train average_precision: 0.7290512643959883
# (ray_tune_sdv pid=85167) Val loss: 0.475911690849037
# (ray_tune_sdv pid=85167) Val accuracy: 0.7734363168256853
# (ray_tune_sdv pid=85167) Val precision: 0.7450128918442123
# (ray_tune_sdv pid=85167) Val recall: 0.8314402544298046
# (ray_tune_sdv pid=85167) Val f1: 0.7858574291440024
# (ray_tune_sdv pid=85167) Val roc_auc: 0.8695115218808499
# (ray_tune_sdv pid=85167) Val pr_auc: 0.8892964516510251
# (ray_tune_sdv pid=85167) Val average_precision: 0.8893533395196083
# (ray_tune_sdv pid=85167) Best val_f1: 0.8144299287410927
# (ray_tune_sdv pid=85167)
# (ray_tune_sdv pid=85167) Training completed!
# (ray_tune_sdv pid=118766) 2024-08-05 00:58:53.025370: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# (ray_tune_sdv pid=118766) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (ray_tune_sdv pid=118766) 2024-08-05 00:58:53.157885: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# (ray_tune_sdv pid=118766) 2024-08-05 00:58:53.633617: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# (ray_tune_sdv pid=118766) 2024-08-05 00:58:53.633679: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# (ray_tune_sdv pid=118766) 2024-08-05 00:58:53.633684: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (ray_tune_sdv pid=118766) Device: 'cuda'
# (ray_tune_sdv pid=118766) Total Number of Parameters: 3463536
# (ray_tune_sdv pid=118766) Total Number of Trainable Parameters: 3463536
# (ray_tune_sdv pid=118766) Starting training loop at 2024-08-05 00:58:55
# (ray_tune_sdv pid=118766) MiniBatches:   0%|          | 0/16525 [00:00<?, ?it/s]
# (ray_tune_sdv pid=118766) Epoch 1
# (ray_tune_sdv pid=118766) New best model saved!
# (ray_tune_sdv pid=118766) Epoch Number: 1
# (ray_tune_sdv pid=118766) Epoch time: 74.63467860221863
# (ray_tune_sdv pid=118766) Train loss: 1.1212072403945588
# (ray_tune_sdv pid=118766) Train accuracy: 0.7924984511599091
# (ray_tune_sdv pid=118766) Train precision: 0.7929370400372279
# (ray_tune_sdv pid=118766) Train recall: 0.7917498451159909
# (ray_tune_sdv pid=118766) Train f1: 0.792342997873055
# (ray_tune_sdv pid=118766) Train roc_auc: 0.8361057185555395
# (ray_tune_sdv pid=118766) Train pr_auc: 0.7970314003843163
# (ray_tune_sdv pid=118766) Train average_precision: 0.7937791765980634
# (ray_tune_sdv pid=118766) Val loss: 0.40477188579414203
# (ray_tune_sdv pid=118766) Val accuracy: 0.82189913675602
# (ray_tune_sdv pid=118766) Val precision: 0.7767217810180966
# (ray_tune_sdv pid=118766) Val recall: 0.9035286990761775
# (ray_tune_sdv pid=118766) Val f1: 0.8353402408288995
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9152272615564052
# (ray_tune_sdv pid=118766) Val pr_auc: 0.9192083618894428
# (ray_tune_sdv pid=118766) Val average_precision: 0.9192124761744026
# (ray_tune_sdv pid=118766) Best val_f1: 0.8353402408288995
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 2
# (ray_tune_sdv pid=118766) New best model saved!
# (ray_tune_sdv pid=118766) Epoch Number: 2
# (ray_tune_sdv pid=118766) Epoch time: 73.9127767086029
# (ray_tune_sdv pid=118766) Train loss: 0.37750516155742864
# (ray_tune_sdv pid=118766) Train accuracy: 0.8441694775246094
# (ray_tune_sdv pid=118766) Train precision: 0.8412449237279459
# (ray_tune_sdv pid=118766) Train recall: 0.8484546017760033
# (ray_tune_sdv pid=118766) Train f1: 0.844834381479514
# (ray_tune_sdv pid=118766) Train roc_auc: 0.91173402146654
# (ray_tune_sdv pid=118766) Train pr_auc: 0.9014293913319734
# (ray_tune_sdv pid=118766) Train average_precision: 0.9014327653032554
# (ray_tune_sdv pid=118766) Val loss: 0.36404194038559273
# (ray_tune_sdv pid=118766) Val accuracy: 0.8463577161896108
# (ray_tune_sdv pid=118766) Val precision: 0.8357310628302995
# (ray_tune_sdv pid=118766) Val recall: 0.8621838558231107
# (ray_tune_sdv pid=118766) Val f1: 0.8487513976891541
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9230941583673375
# (ray_tune_sdv pid=118766) Val pr_auc: 0.9232741860374908
# (ray_tune_sdv pid=118766) Val average_precision: 0.9232783497091501
# (ray_tune_sdv pid=118766) Best val_f1: 0.8487513976891541
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 3
# (ray_tune_sdv pid=118766) New best model saved!
# (ray_tune_sdv pid=118766) Epoch Number: 3
# (ray_tune_sdv pid=118766) Epoch time: 75.80079078674316
# (ray_tune_sdv pid=118766) Train loss: 0.3544281526152783
# (ray_tune_sdv pid=118766) Train accuracy: 0.8535743787430302
# (ray_tune_sdv pid=118766) Train precision: 0.8490867385948517
# (ray_tune_sdv pid=118766) Train recall: 0.8600020651201211
# (ray_tune_sdv pid=118766) Train f1: 0.8545095457537853
# (ray_tune_sdv pid=118766) Train roc_auc: 0.9218152394847744
# (ray_tune_sdv pid=118766) Train pr_auc: 0.9103249277620241
# (ray_tune_sdv pid=118766) Train average_precision: 0.9103279626166557
# (ray_tune_sdv pid=118766) Val loss: 0.35430291662181634
# (ray_tune_sdv pid=118766) Val accuracy: 0.8528699076177495
# (ray_tune_sdv pid=118766) Val precision: 0.8712555768005099
# (ray_tune_sdv pid=118766) Val recall: 0.8281084355595941
# (ray_tune_sdv pid=118766) Val f1: 0.8491342495535367
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9257718400639785
# (ray_tune_sdv pid=118766) Val pr_auc: 0.9271259432202514
# (ray_tune_sdv pid=118766) Val average_precision: 0.927129907297202
# (ray_tune_sdv pid=118766) Best val_f1: 0.8491342495535367
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 4
# (ray_tune_sdv pid=118766) New best model saved!
# (ray_tune_sdv pid=118766) Epoch Number: 4
# (ray_tune_sdv pid=118766) Epoch time: 74.03165698051453
# (ray_tune_sdv pid=118766) Train loss: 0.3455566583028974
# (ray_tune_sdv pid=118766) Train accuracy: 0.8567064775934466
# (ray_tune_sdv pid=118766) Train precision: 0.8522149909089364
# (ray_tune_sdv pid=118766) Train recall: 0.8630825359675087
# (ray_tune_sdv pid=118766) Train f1: 0.857614336893046
# (ray_tune_sdv pid=118766) Train roc_auc: 0.9257674896663083
# (ray_tune_sdv pid=118766) Train pr_auc: 0.9132852673809273
# (ray_tune_sdv pid=118766) Train average_precision: 0.9132878827041645
# (ray_tune_sdv pid=118766) Val loss: 0.3540933898825576
# (ray_tune_sdv pid=118766) Val accuracy: 0.851052551870362
# (ray_tune_sdv pid=118766) Val precision: 0.8334771975255358
# (ray_tune_sdv pid=118766) Val recall: 0.8774042102074815
# (ray_tune_sdv pid=118766) Val f1: 0.8548767891397374
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9244543655196541
# (ray_tune_sdv pid=118766) Val pr_auc: 0.927511969821782
# (ray_tune_sdv pid=118766) Val average_precision: 0.9275153759665653
# (ray_tune_sdv pid=118766) Best val_f1: 0.8548767891397374
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 5
# (ray_tune_sdv pid=118766) Early stopping counter: 1
# (ray_tune_sdv pid=118766) Epoch Number: 5
# (ray_tune_sdv pid=118766) Epoch time: 74.10937857627869
# (ray_tune_sdv pid=118766) Train loss: 0.3383961516855047
# (ray_tune_sdv pid=118766) Train accuracy: 0.8584962483651133
# (ray_tune_sdv pid=118766) Train precision: 0.8528788982433554
# (ray_tune_sdv pid=118766) Train recall: 0.8664555654987265
# (ray_tune_sdv pid=118766) Train f1: 0.8596136280209319
# (ray_tune_sdv pid=118766) Train roc_auc: 0.9287448989374584
# (ray_tune_sdv pid=118766) Train pr_auc: 0.9168160244220466
# (ray_tune_sdv pid=118766) Train average_precision: 0.9168178189906165
# (ray_tune_sdv pid=118766) Val loss: 0.351098316087239
# (ray_tune_sdv pid=118766) Val accuracy: 0.8481750719369984
# (ray_tune_sdv pid=118766) Val precision: 0.8235749472202675
# (ray_tune_sdv pid=118766) Val recall: 0.8861880963198546
# (ray_tune_sdv pid=118766) Val f1: 0.8537350452290634
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9270774509698011
# (ray_tune_sdv pid=118766) Val pr_auc: 0.9299666447585577
# (ray_tune_sdv pid=118766) Val average_precision: 0.9299701017970018
# (ray_tune_sdv pid=118766) Best val_f1: 0.8548767891397374
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 6
# (ray_tune_sdv pid=118766) New best model saved!
# (ray_tune_sdv pid=118766) Epoch Number: 6
# (ray_tune_sdv pid=118766) Epoch time: 74.6008734703064
# (ray_tune_sdv pid=118766) Train loss: 0.32935771086798893
# (ray_tune_sdv pid=118766) Train accuracy: 0.8620069525710745
# (ray_tune_sdv pid=118766) Train precision: 0.8550834725949933
# (ray_tune_sdv pid=118766) Train recall: 0.8717560404763544
# (ray_tune_sdv pid=118766) Train f1: 0.8633392700406479
# (ray_tune_sdv pid=118766) Train roc_auc: 0.9324588530881242
# (ray_tune_sdv pid=118766) Train pr_auc: 0.9196285660272897
# (ray_tune_sdv pid=118766) Train average_precision: 0.919640915327097
# (ray_tune_sdv pid=118766) Val loss: 0.3425229243610216
# (ray_tune_sdv pid=118766) Val accuracy: 0.8519233681659851
# (ray_tune_sdv pid=118766) Val precision: 0.8295865541450961
# (ray_tune_sdv pid=118766) Val recall: 0.8858094805391489
# (ray_tune_sdv pid=118766) Val f1: 0.8567766506756509
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9302561893387622
# (ray_tune_sdv pid=118766) Val pr_auc: 0.9328201941599393
# (ray_tune_sdv pid=118766) Val average_precision: 0.9328235874445958
# (ray_tune_sdv pid=118766) Best val_f1: 0.8567766506756509
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 7
# (ray_tune_sdv pid=118766) New best model saved!
# (ray_tune_sdv pid=118766) Epoch Number: 7
# (ray_tune_sdv pid=118766) Epoch time: 73.6822144985199
# (ray_tune_sdv pid=118766) Train loss: 0.3253155956906369
# (ray_tune_sdv pid=118766) Train accuracy: 0.8629448612927652
# (ray_tune_sdv pid=118766) Train precision: 0.8553496208930076
# (ray_tune_sdv pid=118766) Train recall: 0.8736318579197356
# (ray_tune_sdv pid=118766) Train f1: 0.8643940812886307
# (ray_tune_sdv pid=118766) Train roc_auc: 0.9338669390202076
# (ray_tune_sdv pid=118766) Train pr_auc: 0.9216174786836584
# (ray_tune_sdv pid=118766) Train average_precision: 0.9216249122419252
# (ray_tune_sdv pid=118766) Val loss: 0.3421996091874901
# (ray_tune_sdv pid=118766) Val accuracy: 0.8552173254581251
# (ray_tune_sdv pid=118766) Val precision: 0.8398290350623008
# (ray_tune_sdv pid=118766) Val recall: 0.8778585491443284
# (ray_tune_sdv pid=118766) Val f1: 0.8584228063680119
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9293663161061834
# (ray_tune_sdv pid=118766) Val pr_auc: 0.9298822964556802
# (ray_tune_sdv pid=118766) Val average_precision: 0.9298869639195785
# (ray_tune_sdv pid=118766) Best val_f1: 0.8584228063680119
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 8
# (ray_tune_sdv pid=118766) Early stopping counter: 1
# (ray_tune_sdv pid=118766) Epoch Number: 8
# (ray_tune_sdv pid=118766) Epoch time: 75.2416524887085
# (ray_tune_sdv pid=118766) Train loss: 0.31965157803197264
# (ray_tune_sdv pid=118766) Train accuracy: 0.865319749432092
# (ray_tune_sdv pid=118766) Train precision: 0.856761117273369
# (ray_tune_sdv pid=118766) Train recall: 0.8773146554691265
# (ray_tune_sdv pid=118766) Train f1: 0.8669160785647478
# (ray_tune_sdv pid=118766) Train roc_auc: 0.9357725643468111
# (ray_tune_sdv pid=118766) Train pr_auc: 0.9215679345060944
# (ray_tune_sdv pid=118766) Train average_precision: 0.9215710856642229
# (ray_tune_sdv pid=118766) Val loss: 0.3402753411859706
# (ray_tune_sdv pid=118766) Val accuracy: 0.8573754354081478
# (ray_tune_sdv pid=118766) Val precision: 0.8542902184520682
# (ray_tune_sdv pid=118766) Val recall: 0.8617295168862639
# (ray_tune_sdv pid=118766) Val f1: 0.8579937422249029
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9301610021319228
# (ray_tune_sdv pid=118766) Val pr_auc: 0.9299259286379629
# (ray_tune_sdv pid=118766) Val average_precision: 0.9299315089706829
# (ray_tune_sdv pid=118766) Best val_f1: 0.8584228063680119
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 9
# (ray_tune_sdv pid=118766) New best model saved!
# (ray_tune_sdv pid=118766) Epoch Number: 9
# (ray_tune_sdv pid=118766) Epoch time: 74.44062352180481
# (ray_tune_sdv pid=118766) Train loss: 0.3152338912308479
# (ray_tune_sdv pid=118766) Train accuracy: 0.8671439388724445
# (ray_tune_sdv pid=118766) Train precision: 0.8576409843760477
# (ray_tune_sdv pid=118766) Train recall: 0.8804295449852
# (ray_tune_sdv pid=118766) Train f1: 0.8688858695652174
# (ray_tune_sdv pid=118766) Train roc_auc: 0.9372780162312349
# (ray_tune_sdv pid=118766) Train pr_auc: 0.9232235755466107
# (ray_tune_sdv pid=118766) Train average_precision: 0.9232303590771134
# (ray_tune_sdv pid=118766) Val loss: 0.3354244813826925
# (ray_tune_sdv pid=118766) Val accuracy: 0.8602150537634409
# (ray_tune_sdv pid=118766) Val precision: 0.8555837942891314
# (ray_tune_sdv pid=118766) Val recall: 0.8667272451915796
# (ray_tune_sdv pid=118766) Val f1: 0.8611194703581102
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9317502853064576
# (ray_tune_sdv pid=118766) Val pr_auc: 0.932138292527434
# (ray_tune_sdv pid=118766) Val average_precision: 0.9321433207581661
# (ray_tune_sdv pid=118766) Best val_f1: 0.8611194703581102
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 10
# (ray_tune_sdv pid=118766) Early stopping counter: 1
# (ray_tune_sdv pid=118766) Epoch Number: 10
# (ray_tune_sdv pid=118766) Epoch time: 74.39369869232178
# (ray_tune_sdv pid=118766) Train loss: 0.31110297757229616
# (ray_tune_sdv pid=118766) Train accuracy: 0.8693553383355132
# (ray_tune_sdv pid=118766) Train precision: 0.8587427081418089
# (ray_tune_sdv pid=118766) Train recall: 0.8841467612032766
# (ray_tune_sdv pid=118766) Train f1: 0.8712595921482172
# (ray_tune_sdv pid=118766) Train roc_auc: 0.93849123876307
# (ray_tune_sdv pid=118766) Train pr_auc: 0.9226597276317517
# (ray_tune_sdv pid=118766) Train average_precision: 0.9226628907236261
# (ray_tune_sdv pid=118766) Val loss: 0.3410508927083822
# (ray_tune_sdv pid=118766) Val accuracy: 0.856466757534454
# (ray_tune_sdv pid=118766) Val precision: 0.8627571857902443
# (ray_tune_sdv pid=118766) Val recall: 0.8477964561562926
# (ray_tune_sdv pid=118766) Val f1: 0.8552113967077876
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9303753303154622
# (ray_tune_sdv pid=118766) Val pr_auc: 0.9316609188777143
# (ray_tune_sdv pid=118766) Val average_precision: 0.9316647446166205
# (ray_tune_sdv pid=118766) Best val_f1: 0.8611194703581102
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 11
# (ray_tune_sdv pid=118766) Early stopping counter: 2
# (ray_tune_sdv pid=118766) Epoch Number: 11
# (ray_tune_sdv pid=118766) Epoch time: 73.32547664642334
# (ray_tune_sdv pid=118766) Train loss: 0.3029874667262716
# (ray_tune_sdv pid=118766) Train accuracy: 0.8719109244854409
# (ray_tune_sdv pid=118766) Train precision: 0.8604476616185203
# (ray_tune_sdv pid=118766) Train recall: 0.8878123494183245
# (ray_tune_sdv pid=118766) Train f1: 0.8739158422550481
# (ray_tune_sdv pid=118766) Train roc_auc: 0.941621672447204
# (ray_tune_sdv pid=118766) Train pr_auc: 0.926805485535592
# (ray_tune_sdv pid=118766) Train average_precision: 0.9268182856687653
# (ray_tune_sdv pid=118766) Val loss: 0.3476012369284883
# (ray_tune_sdv pid=118766) Val accuracy: 0.8505224897773739
# (ray_tune_sdv pid=118766) Val precision: 0.8184069335534462
# (ray_tune_sdv pid=118766) Val recall: 0.9009541117673785
# (ray_tune_sdv pid=118766) Val f1: 0.8576989619377163
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9315996589556572
# (ray_tune_sdv pid=118766) Val pr_auc: 0.9329073592977833
# (ray_tune_sdv pid=118766) Val average_precision: 0.9329117545811003
# (ray_tune_sdv pid=118766) Best val_f1: 0.8611194703581102
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 12
# (ray_tune_sdv pid=118766) Early stopping counter: 3
# (ray_tune_sdv pid=118766) Epoch Number: 12
# (ray_tune_sdv pid=118766) Epoch time: 74.26198148727417
# (ray_tune_sdv pid=118766) Train loss: 0.29729259220907867
# (ray_tune_sdv pid=118766) Train accuracy: 0.8750688373373718
# (ray_tune_sdv pid=118766) Train precision: 0.861320645236161
# (ray_tune_sdv pid=118766) Train recall: 0.8940937564535004
# (ray_tune_sdv pid=118766) Train f1: 0.877401268291859
# (ray_tune_sdv pid=118766) Train roc_auc: 0.943088500025984
# (ray_tune_sdv pid=118766) Train pr_auc: 0.9283430494504457
# (ray_tune_sdv pid=118766) Train average_precision: 0.928345163500886
# (ray_tune_sdv pid=118766) Val loss: 0.33234352089356684
# (ray_tune_sdv pid=118766) Val accuracy: 0.8583976980160533
# (ray_tune_sdv pid=118766) Val precision: 0.8472487160674982
# (ray_tune_sdv pid=118766) Val recall: 0.8744510071179766
# (ray_tune_sdv pid=118766) Val f1: 0.8606349679534954
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9340943802959334
# (ray_tune_sdv pid=118766) Val pr_auc: 0.9333393046214162
# (ray_tune_sdv pid=118766) Val average_precision: 0.9333445794691938
# (ray_tune_sdv pid=118766) Best val_f1: 0.8611194703581102
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 13
# (ray_tune_sdv pid=118766) New best model saved!
# (ray_tune_sdv pid=118766) Epoch Number: 13
# (ray_tune_sdv pid=118766) Epoch time: 72.90969753265381
# (ray_tune_sdv pid=118766) Train loss: 0.29429918110764497
# (ray_tune_sdv pid=118766) Train accuracy: 0.8757313967095752
# (ray_tune_sdv pid=118766) Train precision: 0.8615573146093466
# (ray_tune_sdv pid=118766) Train recall: 0.8953328285261926
# (ray_tune_sdv pid=118766) Train f1: 0.8781204111600588
# (ray_tune_sdv pid=118766) Train roc_auc: 0.9439804249845769
# (ray_tune_sdv pid=118766) Train pr_auc: 0.9285066127265977
# (ray_tune_sdv pid=118766) Train average_precision: 0.9285138624901742
# (ray_tune_sdv pid=118766) Val loss: 0.3324871242478274
# (ray_tune_sdv pid=118766) Val accuracy: 0.861540208995911
# (ray_tune_sdv pid=118766) Val precision: 0.8572390572390572
# (ray_tune_sdv pid=118766) Val recall: 0.8675601999091322
# (ray_tune_sdv pid=118766) Val f1: 0.8623687478830304
# (ray_tune_sdv pid=118766) Val roc_auc: 0.9342336504669113
# (ray_tune_sdv pid=118766) Val pr_auc: 0.9352920609080986
# (ray_tune_sdv pid=118766) Val average_precision: 0.935297057667686
# (ray_tune_sdv pid=118766) Best val_f1: 0.8623687478830304
# (ray_tune_sdv pid=118766)
# (ray_tune_sdv pid=118766) Epoch 14
# (ray_tune_sdv pid=118766) Early stopping counter: 1
# (ray_tune_sdv pid=118766) Epoch Number: 14
# (ray_tune_sdv pid=118766) Epoch time: 72.63958621025085
# (ray_tune_sdv pid=118766) Train loss: 0.2899092367895374
# (ray_tune_sdv pid=118766) Train accuracy: 0.8776244234872995
# (ray_tune_sdv pid=118766) Train precision: 0.8613801054018445
# (ray_tune_sdv pid=118766) Train recall: 0.900099814139189
# (ray_tune_sdv pid=118766) Train f1: 0.8803144040125223
# ...
# (ray_tune_sdv pid=676413) Val accuracy: 0.8576026048765713
# (ray_tune_sdv pid=676413) Val precision: 0.8530841121495327
# (ray_tune_sdv pid=676413) Val recall: 0.8640012115704983
# (ray_tune_sdv pid=676413) Val f1: 0.8585079568112561
# (ray_tune_sdv pid=676413) Val roc_auc: 0.931764138641702
# (ray_tune_sdv pid=676413) Val pr_auc: 0.9330014411809824
# (ray_tune_sdv pid=676413) Val average_precision: 0.9330054455440687
# (ray_tune_sdv pid=676413) Best val_f1: 0.8585079568112561
# (ray_tune_sdv pid=676413)
# (ray_tune_sdv pid=676413) Epoch 10
# 2024-08-05 08:33:55,181	ERROR tune_controller.py:1502 -- Trial task failed for trial ray_tune_sdv_67363dff
# Traceback (most recent call last):
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/_private/worker.py", line 2547, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=676413, ip=172.17.88.72, actor_id=f93903f808c984e92143c9af01000000, repr=ray_tune_sdv)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/tune/trainable/trainable.py", line 400, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/air/_internal/util.py", line 91, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/tune/trainable/function_trainable.py", line 716, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/tune/trainable/function_trainable.py", line 823, in _trainable_func
#     handle_output(output)
#   File "/home/mayank/miniconda3/envs/dsn/lib/python3.7/site-packages/ray/tune/trainable/function_trainable.py", line 812, in handle_output
#     "Invalid return or yield value. Either return/yield "
# ValueError: Invalid return or yield value. Either return/yield a single number or a dictionary object in your trainable function.
# (ray_tune_sdv pid=676413) New best model saved!
# (ray_tune_sdv pid=676413) Epoch Number: 10
# (ray_tune_sdv pid=676413) Epoch time: 700.7611758708954
# (ray_tune_sdv pid=676413) Train loss: 0.31510290125895996
# (ray_tune_sdv pid=676413) Train accuracy: 0.8708187411263606
# (ray_tune_sdv pid=676413) Train precision: 0.8605532956616172
# (ray_tune_sdv pid=676413) Train recall: 0.8850544249881684
# (ray_tune_sdv pid=676413) Train f1: 0.87263191294772
# (ray_tune_sdv pid=676413) Train roc_auc: 0.9379635853948995
# (ray_tune_sdv pid=676413) Train pr_auc: 0.9246884827724127
# (ray_tune_sdv pid=676413) Train average_precision: 0.9246907909466541
# (ray_tune_sdv pid=676413) Val loss: 0.3437093556139377
# (ray_tune_sdv pid=676413) Val accuracy: 0.8536650007572315
# (ray_tune_sdv pid=676413) Val precision: 0.8280075848023035
# (ray_tune_sdv pid=676413) Val recall: 0.8927760109041345
# (ray_tune_sdv pid=676413) Val f1: 0.8591728912370196
# (ray_tune_sdv pid=676413) Val roc_auc: 0.9306157338475214
# (ray_tune_sdv pid=676413) Val pr_auc: 0.9302760522792436
# (ray_tune_sdv pid=676413) Val average_precision: 0.9302804544262236
# (ray_tune_sdv pid=676413) Best val_f1: 0.8591728912370196
# (ray_tune_sdv pid=676413)
# (ray_tune_sdv pid=676413) Training completed!
# (ray_tune_sdv pid=1043506) 2024-08-05 08:33:58.304616: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# (ray_tune_sdv pid=1043506) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (ray_tune_sdv pid=1043506) 2024-08-05 08:33:58.412968: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# (ray_tune_sdv pid=1043506) 2024-08-05 08:33:58.877383: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# (ray_tune_sdv pid=1043506) 2024-08-05 08:33:58.877435: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# (ray_tune_sdv pid=1043506) 2024-08-05 08:33:58.877440: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (ray_tune_sdv pid=1043506) Device: 'cuda'
# (ray_tune_sdv pid=1043506) Total Number of Parameters: 7641586
# (ray_tune_sdv pid=1043506) Total Number of Trainable Parameters: 7641586
# (ray_tune_sdv pid=1043506) Starting training loop at 2024-08-05 08:34:01
# (ray_tune_sdv pid=1043506) MiniBatches:   0%|          | 0/49530 [00:00<?, ?it/s]
# (ray_tune_sdv pid=1043506) Epoch 1
# (ray_tune_sdv pid=1043506) New best model saved!
# (ray_tune_sdv pid=1043506) Epoch Number: 1
# (ray_tune_sdv pid=1043506) Epoch time: 861.0219705104828
# (ray_tune_sdv pid=1043506) Train loss: 0.4382792355245637
# (ray_tune_sdv pid=1043506) Train accuracy: 0.8237955513487932
# (ray_tune_sdv pid=1043506) Train precision: 0.8197043045924375
# (ray_tune_sdv pid=1043506) Train recall: 0.8301940369143398
# (ray_tune_sdv pid=1043506) Train f1: 0.8249158249158249
# (ray_tune_sdv pid=1043506) Train roc_auc: 0.8917188960951844
# (ray_tune_sdv pid=1043506) Train pr_auc: 0.8739918917603008
# (ray_tune_sdv pid=1043506) Train average_precision: 0.8740137979956144
# (ray_tune_sdv pid=1043506) Val loss: 0.4034272669021972
# (ray_tune_sdv pid=1043506) Val accuracy: 0.8253445403604422
# (ray_tune_sdv pid=1043506) Val precision: 0.8570597523477105
# (ray_tune_sdv pid=1043506) Val recall: 0.780932909283659
# (ray_tune_sdv pid=1043506) Val f1: 0.8172273069456001
# (ray_tune_sdv pid=1043506) Val roc_auc: 0.9026066208529531
# (ray_tune_sdv pid=1043506) Val pr_auc: 0.9022122325827552
# (ray_tune_sdv pid=1043506) Val average_precision: 0.9022212088351615
# (ray_tune_sdv pid=1043506) Best val_f1: 0.8172273069456001
# (ray_tune_sdv pid=1043506)
# (ray_tune_sdv pid=1043506) Epoch 2
# (ray_tune_sdv pid=1043506) New best model saved!
# (ray_tune_sdv pid=1043506) Epoch Number: 2
# (ray_tune_sdv pid=1043506) Epoch time: 876.3012523651123
# (ray_tune_sdv pid=1043506) Train loss: 0.3614385296866469
# (ray_tune_sdv pid=1043506) Train accuracy: 0.8506578324656886
# (ray_tune_sdv pid=1043506) Train precision: 0.8471225380881885
# (ray_tune_sdv pid=1043506) Train recall: 0.8557501183151917
# (ray_tune_sdv pid=1043506) Train f1: 0.8514144724450974
# (ray_tune_sdv pid=1043506) Train roc_auc: 0.9199036106907209
# (ray_tune_sdv pid=1043506) Train pr_auc: 0.9097531965982213
# (ray_tune_sdv pid=1043506) Train average_precision: 0.9097555354628002
# (ray_tune_sdv pid=1043506) Val loss: 0.3389728888372881
# (ray_tune_sdv pid=1043506) Val accuracy: 0.861805240042405
# (ray_tune_sdv pid=1043506) Val precision: 0.8701006971340046
# (ray_tune_sdv pid=1043506) Val recall: 0.8505982129335151
# (ray_tune_sdv pid=1043506) Val f1: 0.860238933986828
# (ray_tune_sdv pid=1043506) Val roc_auc: 0.9320405402030096
# (ray_tune_sdv pid=1043506) Val pr_auc: 0.9323845818942533
# (ray_tune_sdv pid=1043506) Val average_precision: 0.932389548518263
# (ray_tune_sdv pid=1043506) Best val_f1: 0.860238933986828
# (ray_tune_sdv pid=1043506)
# (ray_tune_sdv pid=1043506) Epoch 3
# (ray_tune_sdv pid=1043506) New best model saved!
# (ray_tune_sdv pid=1043506) Epoch Number: 3
# (ray_tune_sdv pid=1043506) Epoch time: 880.3424341678619
# (ray_tune_sdv pid=1043506) Train loss: 0.35432407810273203
# (ray_tune_sdv pid=1043506) Train accuracy: 0.8536583057264553
# (ray_tune_sdv pid=1043506) Train precision: 0.8494967635724174
# (ray_tune_sdv pid=1043506) Train recall: 0.8596119261713204
# (ray_tune_sdv pid=1043506) Train f1: 0.8545244121604457
# (ray_tune_sdv pid=1043506) Train roc_auc: 0.9226636852208927
# (ray_tune_sdv pid=1043506) Train pr_auc: 0.9115536627047859
# (ray_tune_sdv pid=1043506) Train average_precision: 0.9115558762619244
# (ray_tune_sdv pid=1043506) Val loss: 0.3286006524166073
# (ray_tune_sdv pid=1043506) Val accuracy: 0.8631682568529456
# (ray_tune_sdv pid=1043506) Val precision: 0.8654930650815424
# (ray_tune_sdv pid=1043506) Val recall: 0.8599878842950174
# (ray_tune_sdv pid=1043506) Val f1: 0.8627316924946825
# (ray_tune_sdv pid=1043506) Val roc_auc: 0.9361553821503308
# (ray_tune_sdv pid=1043506) Val pr_auc: 0.9371517884721012
# (ray_tune_sdv pid=1043506) Val average_precision: 0.9371551735797268
# (ray_tune_sdv pid=1043506) Best val_f1: 0.8627316924946825
# (ray_tune_sdv pid=1043506)
# (ray_tune_sdv pid=1043506) Epoch 4
# (ray_tune_sdv pid=1043506) Early stopping counter: 1
# (ray_tune_sdv pid=1043506) Epoch Number: 4
# (ray_tune_sdv pid=1043506) Epoch time: 880.1963438987732
# (ray_tune_sdv pid=1043506) Train loss: 0.34134292573206065
# (ray_tune_sdv pid=1043506) Train accuracy: 0.858760056791292
# (ray_tune_sdv pid=1043506) Train precision: 0.8534342888047594
# (ray_tune_sdv pid=1043506) Train recall: 0.8662943681968764
# (ray_tune_sdv pid=1043506) Train f1: 0.859816244856547
# (ray_tune_sdv pid=1043506) Train roc_auc: 0.9280156191731309
# (ray_tune_sdv pid=1043506) Train pr_auc: 0.9170716348147853
# (ray_tune_sdv pid=1043506) Train average_precision: 0.91707393004428
# (ray_tune_sdv pid=1043506) Val loss: 0.37877613371255037
# (ray_tune_sdv pid=1043506) Val accuracy: 0.8290171134332879
# (ray_tune_sdv pid=1043506) Val precision: 0.7701778385772914
# (ray_tune_sdv pid=1043506) Val recall: 0.9379070119642586
# (ray_tune_sdv pid=1043506) Val f1: 0.8458071565146135
# (ray_tune_sdv pid=1043506) Val roc_auc: 0.933205123467965
# (ray_tune_sdv pid=1043506) Val pr_auc: 0.9333898983615078
# (ray_tune_sdv pid=1043506) Val average_precision: 0.9333935514285524
# (ray_tune_sdv pid=1043506) Best val_f1: 0.8627316924946825
# (ray_tune_sdv pid=1043506)
# (ray_tune_sdv pid=1043506) Device: 'cuda'
# (ray_tune_sdv pid=1043506) Total Number of Parameters: 7641586
# (ray_tune_sdv pid=1043506) Total Number of Trainable Parameters: 7641586
# (ray_tune_sdv pid=1043506) Starting training loop at 2024-08-05 09:32:19
# (ray_tune_sdv pid=1043506) MiniBatches:   0%|          | 0/49530 [00:00<?, ?it/s]
# (ray_tune_sdv pid=1043506) Epoch 1
# (ray_tune_sdv pid=1043506) New best model saved!
# (ray_tune_sdv pid=1043506) Epoch Number: 1
# (ray_tune_sdv pid=1043506) Epoch time: 900.5843422412872
# (ray_tune_sdv pid=1043506) Train loss: 0.4420585176895634
# (ray_tune_sdv pid=1043506) Train accuracy: 0.8241173686701373
# (ray_tune_sdv pid=1043506) Train precision: 0.8185217569251949
# (ray_tune_sdv pid=1043506) Train recall: 0.8329010884997634
# (ray_tune_sdv pid=1043506) Train f1: 0.825648820582109
# (ray_tune_sdv pid=1043506) Train roc_auc: 0.8897013723218379
# (ray_tune_sdv pid=1043506) Train pr_auc: 0.8696924406342152
# (ray_tune_sdv pid=1043506) Train average_precision: 0.8696692661691616
# (ray_tune_sdv pid=1043506) Val loss: 0.3870624808074488
# (ray_tune_sdv pid=1043506) Val accuracy: 0.8384446463728609
# (ray_tune_sdv pid=1043506) Val precision: 0.8601821258763801
# (ray_tune_sdv pid=1043506) Val recall: 0.8082689686506134
# (ray_tune_sdv pid=1043506) Val f1: 0.8334179191879758
# (ray_tune_sdv pid=1043506) Val roc_auc: 0.9098242859242155
# (ray_tune_sdv pid=1043506) Val pr_auc: 0.9166792195373159
# (ray_tune_sdv pid=1043506) Val average_precision: 0.9166833073686957
# (ray_tune_sdv pid=1043506) Best val_f1: 0.8334179191879758
# (ray_tune_sdv pid=1043506)
# (ray_tune_sdv pid=1043506) Epoch 2
# (ray_tune_sdv pid=1043506) New best model saved!
# (ray_tune_sdv pid=1043506) Epoch Number: 2
# (ray_tune_sdv pid=1043506) Epoch time: 914.30411028862
# (ray_tune_sdv pid=1043506) Train loss: 0.36756894913480037
# (ray_tune_sdv pid=1043506) Train accuracy: 0.848679602460956
# (ray_tune_sdv pid=1043506) Train precision: 0.8462608564875738
# (ray_tune_sdv pid=1043506) Train recall: 0.8521722669190724
# (ray_tune_sdv pid=1043506) Train f1: 0.849206274347051
# (ray_tune_sdv pid=1043506) Train roc_auc: 0.9170776887225296
# (ray_tune_sdv pid=1043506) Train pr_auc: 0.9064380497101072
# (ray_tune_sdv pid=1043506) Train average_precision: 0.9064423659968996
# (ray_tune_sdv pid=1043506) Val loss: 0.343558096176274
# (ray_tune_sdv pid=1043506) Val accuracy: 0.8546115402089959
# (ray_tune_sdv pid=1043506) Val precision: 0.8515765765765766
# (ray_tune_sdv pid=1043506) Val recall: 0.8589277601090414
# (ray_tune_sdv pid=1043506) Val f1: 0.8552363718615699
# (ray_tune_sdv pid=1043506) Val roc_auc: 0.9298624558766112
# (ray_tune_sdv pid=1043506) Val pr_auc: 0.932967543654907
# (ray_tune_sdv pid=1043506) Val average_precision: 0.9329706874769412
# (ray_tune_sdv pid=1043506) Best val_f1: 0.8552363718615699
# (ray_tune_sdv pid=1043506)
# (ray_tune_sdv pid=1043506) Epoch 3
# (ray_tune_sdv pid=1043506) Early stopping counter: 1
# (ray_tune_sdv pid=1043506) Epoch Number: 3
# (ray_tune_sdv pid=1043506) Epoch time: 942.1404731273651
# (ray_tune_sdv pid=1043506) Train loss: 0.3574740760443537
# (ray_tune_sdv pid=1043506) Train accuracy: 0.8532513014671084
# (ray_tune_sdv pid=1043506) Train precision: 0.8505306659152813
# (ray_tune_sdv pid=1043506) Train recall: 0.8571320397539044
# (ray_tune_sdv pid=1043506) Train f1: 0.8538185932491043
# (ray_tune_sdv pid=1043506) Train roc_auc: 0.9212908548684153
# (ray_tune_sdv pid=1043506) Train pr_auc: 0.9108430344164024
# (ray_tune_sdv pid=1043506) Train average_precision: 0.9108455619506894
# (ray_tune_sdv pid=1043506) Val loss: 0.3482491265122707
# (ray_tune_sdv pid=1043506) Val accuracy: 0.8490458882326215
# (ray_tune_sdv pid=1043506) Val precision: 0.825552652023448
# (ray_tune_sdv pid=1043506) Val recall: 0.8851279721338785
# (ray_tune_sdv pid=1043506) Val f1: 0.854302941713868
# (ray_tune_sdv pid=1043506) Val roc_auc: 0.9282931499454502
# (ray_tune_sdv pid=1043506) Val pr_auc: 0.9305278791639604
# (ray_tune_sdv pid=1043506) Val average_precision: 0.9305316392621727
# (ray_tune_sdv pid=1043506) Best val_f1: 0.8552363718615699
# (ray_tune_sdv pid=1043506)
# (ray_tune_sdv pid=1043506) Epoch 4
# 2024-08-05 10:30:17,171	WARNING tune.py:195 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-08-05 10:30:27,190	ERROR tune.py:1139 -- Trials did not complete: [ray_tune_sdv_1d2160e6, ray_tune_sdv_f5b47831, ray_tune_sdv_1d96640c, ray_tune_sdv_afbfd312, ray_tune_sdv_796b45b0, ray_tune_sdv_2c093bc7, ray_tune_sdv_67363dff]
# 2024-08-05 10:30:27,192	INFO tune.py:1144 -- Total run time: 35007.40 seconds (34997.14 seconds for the tuning loop).
# 2024-08-05 10:30:27,193	WARNING tune.py:1159 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: Tuner.restore(path="/root/SDV-HGNN/hyperparam/ray_results/ray_tune_sdv_2024-08-05_00-46-59", trainable=...)
# 2024-08-05 10:30:27,230	WARNING experiment_analysis.py:206 -- Failed to fetch metrics for 1 trial(s):
# - ray_tune_sdv_b1763bdc: FileNotFoundError('Could not fetch metrics for ray_tune_sdv_b1763bdc: both result.json and progress.csv were not found at /root/SDV-HGNN/hyperparam/ray_results/ray_tune_sdv_2024-08-05_00-46-59/ray_tune_sdv_b1763bdc_22_batch_size=16,dtr=0.4500,num_neigh1=10,num_neigh2=10,mol_block_param=2,mol_heads_out=128,mol_n_head=4,out_2024-08-05_09-32-19')

# %%
best_params_list = "load_data/batch_size	load_data/dtr	load_data/num_neigh1	load_data/num_neigh2	model/mol_block_para m	model/mol_heads_out	model/mol_n_head	model/outer_block	model/outer_hidden_d ims	model/outer_n_head	training/decay	training/lr	training/n_epochs"
best_params_list = best_params_list.split("\t")
best_params = "32	0.5	12	10	1	16	3	2	128	3	1.01015e-05	0.00143381	25"
best_params = best_params.split("\t")
# Out:
# ['load_data/batch_size',
#  'load_data/dtr',
#  'load_data/num_neigh1',
#  'load_data/num_neigh2',
#  'model/mol_block_para m',
#  'model/mol_heads_out',
#  'model/mol_n_head',
#  'model/outer_block',
#  'model/outer_hidden_d ims',
#  'model/outer_n_head',
#  'training/decay',
#  'training/lr',
#  'training/n_epochs']

# %%
best_param_dict = dict(zip(best_params_list, best_params))
best_param_dict
# Out:
# {'load_data/batch_size': '32',
#  'load_data/dtr': '0.5',
#  'load_data/num_neigh1': '12',
#  'load_data/num_neigh2': '10',
#  'model/mol_block_para m': '1',
#  'model/mol_heads_out': '16',
#  'model/mol_n_head': '3',
#  'model/outer_block': '2',
#  'model/outer_hidden_d ims': '128',
#  'model/outer_n_head': '3',
#  'training/decay': '1.01015e-05',
#  'training/lr': '0.00143381',
#  'training/n_epochs': '25'}

# %%
print("Best config is:", results.get_best_result().config)
# Out:
# 192
